# %% [markdown]
# # Prediction for tips

# %%
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# ## General Idea
#
# * Take subset with tipping (only Credit!)
# * Calculate percentige
# * Get duration
# * Get average speed
# * Get locations (tipping may be dependant on pickup/dropoff loc)
#     * Maybe data will get to big -> take subset before

# %%
# Manage imports
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt
df = pd.read_csv("clean.csv")

# %%
df.describe()
# Out:
#          Unnamed: 0  passenger_count  trip_distance  pickup_longitude  \
# count  9.089862e+06     9.089862e+06   9.089862e+06      9.089862e+06
# mean   5.563865e+06     1.662580e+00   2.772811e+00     -7.397496e+01
# std    3.215233e+06     1.309217e+00   3.348655e+00      3.519076e-02
# min    0.000000e+00     1.000000e+00   0.000000e+00     -7.497944e+01
# 25%    2.773322e+06     1.000000e+00   1.000000e+00     -7.399203e+01
# 50%    5.562318e+06     1.000000e+00   1.700000e+00     -7.398177e+01
# 75%    8.355590e+06     2.000000e+00   3.100000e+00     -7.396763e+01
# max    1.113547e+07     6.000000e+00   8.059000e+02     -7.306319e+01
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     9.089862e+06  9.089862e+06       9.089862e+06      9.089862e+06
# mean      4.075148e+01  1.026148e+00      -7.397426e+01      4.075215e+01
# std       2.751583e-02  2.281444e-01       3.448350e-02      3.179048e-02
# min       3.989138e+01  1.000000e+00      -7.496015e+01      3.978150e+01
# 25%       4.073790e+01  1.000000e+00      -7.399139e+01      4.073651e+01
# 50%       4.075437e+01  1.000000e+00      -7.397975e+01      4.075474e+01
# 75%       4.076844e+01  1.000000e+00      -7.396333e+01      4.076988e+01
# max       4.174065e+01  5.000000e+00      -7.298619e+01      4.174065e+01
#
#        payment_type   fare_amount         extra       mta_tax    tip_amount  \
# count  9.089862e+06  9.089862e+06  9.089862e+06  9.089862e+06  9.089862e+06
# mean   1.393751e+00  1.258419e+01  3.310450e-01  4.983148e-01  1.626609e+00
# std    5.028901e-01  1.004340e+01  4.213210e-01  2.897839e-02  2.377480e+00
# min    1.000000e+00  3.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  6.500000e+00  0.000000e+00  5.000000e-01  0.000000e+00
# 50%    1.000000e+00  9.500000e+00  0.000000e+00  5.000000e-01  1.000000e+00
# 75%    2.000000e+00  1.500000e+01  5.000000e-01  5.000000e-01  2.250000e+00
# max    5.000000e+00  2.000000e+02  4.500000e+00  5.000000e-01  1.000000e+02
#
#        tolls_amount  total_amount
# count  9.089862e+06  9.089862e+06
# mean   1.913909e-01  1.553155e+01
# std    1.184831e+00  1.239795e+01
# min    0.000000e+00  3.300000e+00
# 25%    0.000000e+00  8.300000e+00
# 50%    0.000000e+00  1.180000e+01
# 75%    0.000000e+00  1.780000e+01
# max    3.000000e+01  2.759500e+02

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9089862 entries, 0 to 9089861
# Data columns (total 18 columns):
# Unnamed: 0               int64
# tpep_pickup_datetime     object
# tpep_dropoff_datetime    object
# passenger_count          int64
# trip_distance            float64
# pickup_longitude         float64
# pickup_latitude          float64
# RatecodeID               int64
# dropoff_longitude        float64
# dropoff_latitude         float64
# payment_type             int64
# fare_amount              float64
# extra                    float64
# mta_tax                  float64
# tip_amount               float64
# tolls_amount             float64
# total_amount             float64
# duration                 object
# dtypes: float64(11), int64(4), object(3)
# memory usage: 1.2+ GB

# %%
df.head()
# Out:
#    Unnamed: 0 tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           0  2016-06-09 21:06:36   2016-06-09 21:13:08                2
# 1           1  2016-06-09 21:06:36   2016-06-09 21:35:11                1
# 2           3  2016-06-09 21:06:36   2016-06-09 21:36:10                1
# 3           4  2016-06-09 21:06:36   2016-06-09 21:23:23                1
# 4           5  2016-06-09 21:06:36   2016-06-09 21:19:21                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           0.79        -73.983360        40.760937           1
# 1           5.22        -73.981720        40.736668           1
# 2           7.39        -73.982361        40.773891           1
# 3           3.10        -73.987106        40.733173           1
# 4           2.17        -73.995201        40.739491           1
#
#    dropoff_longitude  dropoff_latitude  payment_type  fare_amount  extra  \
# 0         -73.977463         40.753979             2          6.0    0.5
# 1         -73.981636         40.670242             1         22.0    0.5
# 2         -73.929466         40.851540             1         26.0    0.5
# 3         -73.985909         40.766445             1         13.5    0.5
# 4         -73.993202         40.762642             1         10.5    0.5
#
#    mta_tax  tip_amount  tolls_amount  total_amount                   duration
# 0      0.5        0.00           0.0          7.30  0 days 00:06:32.000000000
# 1      0.5        4.00           0.0         27.30  0 days 00:28:35.000000000
# 2      0.5        1.00           0.0         28.30  0 days 00:29:34.000000000
# 3      0.5        2.96           0.0         17.76  0 days 00:16:47.000000000
# 4      0.5        2.36           0.0         14.16  0 days 00:12:45.000000000

# %%
df = df.drop('Unnamed: 0', axis=1)

# %% [markdown]
# ## Explore

# %%
import reverse_geocoder as rg

# %%
df[df.RatecodeID == 3].head()
# Out:
#      tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 84    2016-06-09 21:13:23   2016-06-09 21:43:05                1
# 2539  2016-06-09 21:14:51   2016-06-09 21:49:26                1
# 3469  2016-06-09 21:15:35   2016-06-09 21:52:38                1
# 5418  2016-06-09 21:20:53   2016-06-09 21:59:04                5
# 8243  2016-06-09 21:26:15   2016-06-09 21:57:04                2
#
#       trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 84            16.36        -73.995018        40.750259           3
# 2539          14.72        -73.975258        40.754181           3
# 3469          14.00        -73.988045        40.732834           3
# 5418          14.00        -74.015244        40.708679           3
# 8243          10.86        -73.984238        40.763847           3
#
#       dropoff_longitude  dropoff_latitude  tip_amount  total_amount  \
# 84           -74.185753         40.689320       22.76         98.64
# 2539         -74.163918         40.735260       14.36         86.16
# 3469         -74.177643         40.690327       14.25         85.55
# 5418         -74.177582         40.690472       10.00         82.30
# 8243         -74.040077         40.840382        7.00         73.30
#
#                        duration  subtotal   tip_perc
# 84    0 days 00:29:42.000000000     75.88  29.994729
# 2539  0 days 00:34:35.000000000     71.80  20.000000
# 3469  0 days 00:37:03.000000000     71.30  19.985975
# 5418  0 days 00:38:11.000000000     72.30  13.831259
# 8243  0 days 00:30:49.000000000     66.30  10.558069

# %%
df['pickup_coord']=list(zip(df.pickup_latitude, df.pickup_longitude))
df['dropoff_coord']=list(zip(df.dropoff_latitude, df.dropoff_longitude))

# %%
ax = df.groupby(['RatecodeID']).size().plot(kind='bar', figsize=(15, 5))

ax.set_xlabel('Ratecode', fontsize=18)
ax.set_ylabel('Number of trips', fontsize=18)
ax.tick_params(labelsize=12)

# %%
ax = df.groupby('passenger_count').size().plot(kind='bar')

ax.set_xlabel('passenger_count', fontsize=18)
ax.set_ylabel('Number of trips', fontsize=18)
ax.tick_params(labelsize=12)

# %%
data = df.sample(100000)

pickup_x = data.pickup_longitude.values
pickup_y = data.pickup_latitude.values
dropoff_x = data.dropoff_longitude.values
dropoff_y = data.dropoff_latitude.values

margin = 0.3
long_min = 40.756716 - margin
long_max = 40.756716 + margin
lat_min = -73.985368 - margin
lat_max = -73.985368 + margin

# %%
fig, ax = plt.subplots(figsize=(11, 12))

ax.scatter(pickup_x, pickup_y, s=5, color='blue', alpha=0.5)
ax.scatter(dropoff_x, dropoff_y, s=5, color='red', alpha=0.5)



ax.set_xlim([lat_min, lat_max])
ax.set_ylim([long_min, long_max])

ax.set_title('coordinates')
# Out:
# Text(0.5,1,'coordinates')

# %%
fig, ax = plt.subplots(figsize=(11, 12))

ax.scatter(pickup_x, pickup_y, s=5, c=data.RatecodeID, alpha=0.5)
ax.set_xlim([lat_min, lat_max])
ax.set_ylim([long_min, long_max])

ax.set_title('coordinates')
# Out:
# Text(0.5,1,'coordinates')

# %%
tip_values = data.tip_perc.values

fig, ax = plt.subplots(figsize=(11, 12))

ax.scatter(pickup_x, pickup_y, s=15, c=tip_values, alpha=0.5)


ax.set_xlim([lat_min, lat_max])
ax.set_ylim([long_min, long_max])

ax.set_title('coordinates')
# Out:
# Text(0.5,1,'coordinates')

# %%
tip_values = data.tip_perc.values

fig, ax = plt.subplots(figsize=(11, 12))

ax.scatter(dropoff_x, dropoff_y, s=15, c=tip_values, alpha=0.5)


ax.set_xlim([lat_min, lat_max])
ax.set_ylim([long_min, long_max])

ax.set_title('coordinates')
# Out:
# Text(0.5,1,'coordinates')

# %%
# Coordinates variables.
min_x = -74.361107
min_y = 40.459518

max_x = -71.903083
max_y = 41.175342

step_x = 0.003205  # 270 meters (885 feet) approximately.
step_y = 0.002429  # 270 meters (885 feet) approximately.

# Number of maximum areas per axis in the 'area matrix'.
max_area_x = 766  # int((max_x - min_x) / step_x)
max_area_y = 294  # int((max_y - min_y) / step_y)

# Number of columns of the 'area matrix'.
num_columns = 767  # max_area_x + 1

# The area at the top right corner in the 'area matrix'.
max_area = 226264  # (max_area_y * num_columns) + max_area_x

# Minimum number of pickups or dropoffs per area.
min_area_number = 20


# Columns for creating the pickup and dropoff area attributes.
area_column_names = ['pickup_area', 'dropoff_area']
area_necesary_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']


# Functions for calculating the pickup and dropoff areas in the 'area matrix'.

def get_1d_area(coor, min_coor, step_coor):
    return int((coor - min_coor) / step_coor)

def get_area(area_x, area_y, columns):
    return (area_y * columns) + area_x

def calculate_area(row):
    pickup_x = get_1d_area(row.pickup_longitude, min_x, step_x)
    pickup_y = get_1d_area(row.pickup_latitude, min_y, step_y)
    pickup_area = get_area(pickup_x, pickup_y, num_columns)
    
    dropoff_x = get_1d_area(row.dropoff_longitude, min_x, step_x)
    dropoff_y = get_1d_area(row.dropoff_latitude, min_y, step_y)
    dropoff_area = get_area(dropoff_x, dropoff_y, num_columns)
    
    return pd.Series({
        area_column_names[0]: pickup_area,
        area_column_names[1]: dropoff_area
    })

# %%
for column in area_column_names:
    data[column] = np.nan

data = iterate_and_apply(data, calculate_area, area_necesary_columns)

# %%
color_list = ['red', 'cyan']

pickup = data.groupby(['pickup_area']).size().index
dropoff = data.groupby(['dropoff_area']).size().index

areas = np.concatenate([pickup, dropoff])
areas = np.unique(areas)

# %%
fig, ax = plt.subplots(figsize=(22, 24))
for area in areas.tolist():
   # if area % 2 == 0:
   #     color = color_list[0]
   # else:
   #     color = color_list[1]
    data_pickup = data[(data.pickup_area == area)]
    data_dropoff = data[(data.dropoff_area == area)]
    pickup_x = data_pickup.pickup_longitude.values
    pickup_y = data_pickup.pickup_latitude.values
    dropoff_x = data_dropoff.dropoff_longitude.values
    dropoff_y = data_dropoff.dropoff_latitude.values
    areaAvg = data[(data.pickup_area == data_pickup)].tip_perc.mean()
    ax.scatter(pickup_x, pickup_y, s=5, c=m.to_rgba(areaAvg), alpha=0.5)
    ax.scatter(dropoff_x, dropoff_y, s=5, c=m.to_rgba(areaAvg), alpha=0.5)

ax.set_xlim([-74.1, -73.7])
ax.set_ylim([40.6, 40.9])

ax.set_title('coordinates')

# %%
for area in pickup.tolist():
     print(data[(data.pickup_area == area)].tip_perc.mean())

# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize

cmap = cm.autumn
norm = Normalize(vmin=10, vmax=40)
m = cm.ScalarMappable(norm=norm, cmap=cmap)

m.to_rgba(25)

# %%
data.head()

# %% [markdown]
# ## Constants

# %%
# Tip percentage variables.
tip_perc_necesary_columns = ['fare_amount', 'extra', 'mta_tax', 'tip_amount']
tip_perc_column_name = 'tip_perc'


# Coordinates variables.
min_x = -74.361107
min_y = 40.459518

max_x = -71.903083
max_y = 41.175342

step_x = 0.003205  # 270 meters (885 feet) approximately.
step_y = 0.002429  # 270 meters (885 feet) approximately.

# Number of maximum areas per axis in the 'area matrix'.
max_area_x = 766  # int((max_x - min_x) / step_x)
max_area_y = 294  # int((max_y - min_y) / step_y)

# Number of columns of the 'area matrix'.
num_columns = 767  # max_area_x + 1

# The area at the top right corner in the 'area matrix'.
max_area = 226264  # (max_area_y * num_columns) + max_area_x

# Minimum number of pickups or dropoffs per area.
min_area_number = 20

# Columns for creating the pickup and dropoff area attributes.
area_column_names = ['pickup_area', 'dropoff_area']
area_necesary_columns = ['pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude']

# %% [markdown]
# ## Functions

# %%
# FUNCTIONS

# Functions for calculating. the pickup and dropoff areas in the 'area matrix'.
def get_1d_area(coor, min_coor, step_coor):
    return int((coor - min_coor) / step_coor)

def get_area(area_x, area_y, columns):
    return (area_y * columns) + area_x

def calculate_area(row):
    pickup_x = get_1d_area(row.pickup_longitude, min_x, step_x)
    pickup_y = get_1d_area(row.pickup_latitude, min_y, step_y)
    pickup_area = get_area(pickup_x, pickup_y, num_columns)
    
    dropoff_x = get_1d_area(row.dropoff_longitude, min_x, step_x)
    dropoff_y = get_1d_area(row.dropoff_latitude, min_y, step_y)
    dropoff_area = get_area(dropoff_x, dropoff_y, num_columns)
    
    return pd.Series({
        area_column_names[0]: pickup_area,
        area_column_names[1]: dropoff_area
    })


# This auxiliary function applies another one to every row in a DataFrame for creating new columns.
def iterate_and_apply(dataframe, function, necesary_columns):
    perform = True
    step = 100000
    start = 0
    to = step
    
    while perform:
        new_columns = dataframe[start:to][necesary_columns].apply(function, axis=1)
        if len(new_columns) == 0:
            perform = False
        else:
            dataframe.update(new_columns)
        new_columns = None
        start += step
        to += step
    
    return dataframe

# %%
#cords for a polygon around manhatten, manually set via google maps
manhattan_cords = [(40.882207, -73.933869), #1
         (40.872343, -73.908292), #2
         (40.836117, -73.933011), #3
         (40.804680, -73.931123), #4
         (40.798833, -73.918591), #5
         (40.739289, -73.967000), #6
         (40.707155, -73.973866), #7
         (40.699217, -74.021416), #8
         (40.759316, -74.012662)] #9

# %%
queens_cords =

# %% [markdown]
# ## Feature Eng

# %%
df.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08                2           0.79
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11                1           5.22
# 2  2016-06-09 21:06:36   2016-06-09 21:36:10                1           7.39
# 3  2016-06-09 21:06:36   2016-06-09 21:23:23                1           3.10
# 4  2016-06-09 21:06:36   2016-06-09 21:19:21                1           2.17
#
#    pickup_longitude  pickup_latitude  RatecodeID  dropoff_longitude  \
# 0        -73.983360        40.760937           1         -73.977463
# 1        -73.981720        40.736668           1         -73.981636
# 2        -73.982361        40.773891           1         -73.929466
# 3        -73.987106        40.733173           1         -73.985909
# 4        -73.995201        40.739491           1         -73.993202
#
#    dropoff_latitude  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0         40.753979             2          6.0    0.5      0.5        0.00
# 1         40.670242             1         22.0    0.5      0.5        4.00
# 2         40.851540             1         26.0    0.5      0.5        1.00
# 3         40.766445             1         13.5    0.5      0.5        2.96
# 4         40.762642             1         10.5    0.5      0.5        2.36
#
#    tolls_amount  total_amount                   duration
# 0           0.0          7.30  0 days 00:06:32.000000000
# 1           0.0         27.30  0 days 00:28:35.000000000
# 2           0.0         28.30  0 days 00:29:34.000000000
# 3           0.0         17.76  0 days 00:16:47.000000000
# 4           0.0         14.16  0 days 00:12:45.000000000

# %%
df = df[df.payment_type==1]

# %%
# drop unused variables
df = df.drop(['fare_amount',"payment_type",'tolls_amount','extra','mta_tax'],axis=1)

# %%
# Calculate subtotal
df['subtotal'] = df.total_amount - df.tip_amount

# %%
# Calculating the tip percentage.
df['tip_perc'] = (df.tip_amount / df.subtotal) * 100

# %%
df = df.drop(df[df.tip_perc > 50].index)

# %%
df['duration'] = pd.to_datetime(df["tpep_dropoff_datetime"])-pd.to_datetime(df["tpep_pickup_datetime"])

# %%
df['duration'] = df.duration.dt.total_seconds()

# %%
# Calulcate avg speed (mph)
df['mph'] = (df.trip_distance)/(df.duration/3600)

# %%
df.mph.mean()
# Out:
# 11.68911451739263

# %%
df = df.drop(df[(df.trip_distance < 0.1) | (df.trip_distance > 100) ].index)

# %%
df = df.drop(df[(df.mph < 0.5) | (df.mph > 80) ].index)

# %%
df['pickup_hour'] = pd.to_datetime(df.tpep_pickup_datetime).dt.hour

# %%
ax = df.groupby(['pickup_hour']).subtotal.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(10, 20)
ax.set_xlabel('Hour', fontsize=18)
ax.set_ylabel('Subtotal', fontsize=18)
ax.tick_params(labelsize=12)

# %%
ax = df.groupby(['pickup_hour']).tip_perc.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(15, 20)
ax.set_xlabel('Hour', fontsize=18)
ax.set_ylabel('Tip Percentage', fontsize=18)
ax.tick_params(labelsize=12)

# %%
ax = df.groupby(['pickup_hour']).tip_amount.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(1.5, 4)
ax.set_xlabel('Hour', fontsize=18)
ax.set_ylabel('Total tip', fontsize=18)
ax.tick_params(labelsize=12)

# %%
df['weekday'] = pd.to_datetime(df.tpep_pickup_datetime).dt.weekday_name

# %%
ax = df.groupby(['weekday']).tip_perc.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(15, 20)
ax.set_xlabel('Hour', fontsize=18)
ax.set_ylabel('Tip Percentage', fontsize=18)
ax.tick_params(labelsize=12)

# %%
bins =  np.arange(0,30,1)
#bins = [0, 1, 5, 10, 25, 50, 100]

ind = np.digitize(df['trip_distance'],bins)

ax = df.groupby(ind).tip_perc.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(15, 20)
ax.set_xlabel('Miles', fontsize=18)
ax.set_ylabel('Tip Percentage', fontsize=18)
ax.tick_params(labelsize=12)

# %%
bins =  np.arange(0,25,1)
#bins = [0, 1, 5, 10, 25, 50, 100]

ind = np.digitize(df['mph'],bins)

ax = df.groupby(ind).tip_perc.mean().plot(kind='bar', figsize=(15, 5))
ax.set_ylim(15, 20)
ax.set_xlabel('Miles per hour', fontsize=18)
ax.set_ylabel('Tip Percentage', fontsize=18)
ax.tick_params(labelsize=12)

# %% [markdown]
# ## Baseline

# %% [markdown]
# Calulcate the avg
#
# Use as prediction baseline

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test \
    = train_test_split(df[['subtotal','tip_perc']]\
                     ,df['tip_amount'], test_size=0.2, random_state=1337)

# %%
avg = (X_train.tip_perc.mean()/100)

# %%
avg
# Out:
# 0.1790969702803198

# %%
baseline = (X_test.subtotal*avg).values

# %%
err = pd.DataFrame(y_test-baseline)
err.describe()
# Out:
#          tip_amount
# count  1.107587e+06
# mean  -2.023950e-02
# std    1.293511e+00
# min   -3.910403e+01
# 25%   -3.819897e-01
# 50%    1.839467e-01
# 75%    4.243315e-01
# max    3.021656e+01

# %%
mean_squared_error(y_test,baseline)
# Out:
# 1.673578853158867

# %% [markdown]
# ## test different Regressors and compare

# %%
interize_columns = ['pickup_month', 'pickup_weekday', 'pickup_non_working_today', 'pickup_non_working_tomorrow']

# %%
sample = df.sample(10)

# %%
df_with_dummies = pd.get_dummies(df, columns = ['weekday','pickup_hour'] )

# %%
df_train = df[['pickup_hour','weekday','trip_distance','subtotal', 'RatecodeID','mph',\
                'pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude']]
df_train = pd.get_dummies(df_train, columns = ['weekday','pickup_hour','RatecodeID'] )

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5537931 entries, 1 to 9089861
# Data columns (total 43 columns):
# trip_distance        float64
# subtotal             float64
# mph                  float64
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# weekday_Friday       uint8
# weekday_Monday       uint8
# weekday_Saturday     uint8
# weekday_Sunday       uint8
# weekday_Thursday     uint8
# weekday_Tuesday      uint8
# weekday_Wednesday    uint8
# pickup_hour_0        uint8
# pickup_hour_1        uint8
# pickup_hour_2        uint8
# pickup_hour_3        uint8
# pickup_hour_4        uint8
# pickup_hour_5        uint8
# pickup_hour_6        uint8
# pickup_hour_7        uint8
# pickup_hour_8        uint8
# pickup_hour_9        uint8
# pickup_hour_10       uint8
# pickup_hour_11       uint8
# pickup_hour_12       uint8
# pickup_hour_13       uint8
# pickup_hour_14       uint8
# pickup_hour_15       uint8
# pickup_hour_16       uint8
# pickup_hour_17       uint8
# pickup_hour_18       uint8
# pickup_hour_19       uint8
# pickup_hour_20       uint8
# pickup_hour_21       uint8
# pickup_hour_22       uint8
# pickup_hour_23       uint8
# RatecodeID_1         uint8
# RatecodeID_2         uint8
# RatecodeID_3         uint8
# RatecodeID_4         uint8
# RatecodeID_5         uint8
# dtypes: float64(7), uint8(36)
# memory usage: 688.1 MB

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_train,df['tip_amount'], test_size=0.2, random_state=1337)

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(random_state=1337)

rfr.fit(X_train,y_train)

# %%
rfr_pred = rfr.predict(X_test)

# %%
err = pd.DataFrame(y_test-rfr_pred)
err.describe()

# %%
ax = sns.distplot(err,hist_kws={"log":True},kde=False);

# %%
# Feature importance# Feature 
pd.DataFrame({"Features" : X_train.columns,"estimatedCoefficients": rfr.feature_importances_})

# %%
mean_squared_error(rfr_pred,y_test)

# %% [markdown]
# ## Light GBM

# %%
import lightgbm as lgb

d_train = lgb.Dataset(X_train, label=y_train)
params = {}
params['learning_rate'] = 0.003
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['metric'] = 'binary_logloss'
params['sub_feature'] = 0.5
params['num_leaves'] = 10
params['min_data'] = 50
params['max_depth'] = 10
clf = lgb.train(params, d_train, 100)
