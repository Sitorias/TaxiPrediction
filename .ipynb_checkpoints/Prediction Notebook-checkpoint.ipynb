# %% [markdown]
# # Load Data (already cleaned)

# %%
# Manage imports
import numpy as np
import pandas as pd
import seaborn as sns  
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

pd.options.mode.chained_assignment = None  # default='warn'

# %%
# read data in memory
train = pd.read_csv("C:\\Users\\Leo\\TaxiData\\clean_v2.csv",index_col=0)
# Out:
# E:\Anaconda\lib\site-packages\numpy\lib\arraysetops.py:466: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
test = pd.read_csv("C:\\Users\\Leo\\Dropbox\\Info Göttingen\\Practical Course Data Science\\Task 2\\data\\test_data_v2.csv",engine="python")

# %%
train.head()
# Out:
#   tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  trip_distance  \
# 0  2016-06-09 21:06:36   2016-06-09 21:13:08                2           0.79
# 1  2016-06-09 21:06:36   2016-06-09 21:35:11                1           5.22
# 3  2016-06-09 21:06:36   2016-06-09 21:36:10                1           7.39
# 4  2016-06-09 21:06:36   2016-06-09 21:23:23                1           3.10
# 5  2016-06-09 21:06:36   2016-06-09 21:19:21                1           2.17
#
#    pickup_longitude  pickup_latitude  RatecodeID  dropoff_longitude  \
# 0        -73.983360        40.760937           1         -73.977463
# 1        -73.981720        40.736668           1         -73.981636
# 3        -73.982361        40.773891           1         -73.929466
# 4        -73.987106        40.733173           1         -73.985909
# 5        -73.995201        40.739491           1         -73.993202
#
#    dropoff_latitude  payment_type        ...          subtotal  tip_perc  \
# 0         40.753979             2        ...               7.3  0.000000
# 1         40.670242             1        ...              23.3  0.171674
# 3         40.851540             1        ...              27.3  0.036630
# 4         40.766445             1        ...              14.8  0.200000
# 5         40.762642             1        ...              11.8  0.200000
#
#    pickup_hour                             pickup_coord  \
# 0           21  (40.76093673706055, -73.98336029052734)
# 1           21  (40.73666763305664, -73.98171997070312)
# 3           21  (40.77389144897461, -73.98236083984375)
# 4           21  (40.73317337036133, -73.98710632324219)
# 5           21   (40.7394905090332, -73.99520111083984)
#
#                              dropoff_coord  avg_speed  holiday  overnight  \
# 0  (40.75397872924805, -73.97746276855469)   7.255102    False       True
# 1  (40.67024230957031, -73.98163604736328)  10.957434    False       True
# 3  (40.851539611816406, -73.9294662475586)  14.996618    False       True
# 4   (40.7664451599121, -73.98590850830078)  11.082423    False       True
# 5  (40.76264190673828, -73.99320220947266)  10.211765    False       True
#
#         day  ridesAtPickupHour
# 0  Thursday            20311.8
# 1  Thursday            20311.8
# 3  Thursday            20311.8
# 4  Thursday            20311.8
# 5  Thursday            20311.8
#
# [5 rows x 27 columns]

# %% [markdown]
# # Prepare the Test set (add features)

# %% [markdown]
# ## Add duration in seconds

# %%
test["tpep_pickup_datetime"] = pd.to_datetime(test.tpep_pickup_datetime)
test['tpep_dropoff_datetime'] = pd.to_datetime(test.tpep_dropoff_datetime)

# %%
# Get duration
test['duration'] = pd.to_datetime(test["tpep_dropoff_datetime"])-pd.to_datetime(test["tpep_pickup_datetime"])

# %%
# %%time
test["duration"] = test.apply(lambda x : x.duration.total_seconds(),axis=1)
# Out:
# Wall time: 3.25 s

# %% [markdown]
# ## Calculate average speed

# %%
test = test.assign(avg_speed = test.trip_distance/test.duration*60*60)

# %%
test.avg_speed.describe()
# Out:
# count    64000.000000
# mean        14.546904
# std          9.388043
# min          0.014337
# 25%          8.153310
# 50%         11.716077
# 75%         18.140034
# max        176.170213
# Name: avg_speed, dtype: float64

# %% [markdown]
# ## Append Traffic data from train set

# %%
traffic = train.groupby(["day"])

# %%
trafficPerDay = pd.DataFrame()
for name, group in traffic:
    #group by hour
    pickupDate = group.tpep_pickup_datetime.str.split(" ").str[0];
    dates = pickupDate.unique()
    
    hours = group.groupby(["pickup_hour"]).trip_distance.count()
    
    trafficPerDay = trafficPerDay.append(pd.DataFrame({"day":name,"rides":hours/len(dates),"pickup_hour":hours.index},index=None))  
    print(name,dates,hours/len(dates))
# Out:
# Friday ['2016-06-10' '2016-06-03' '2016-06-17' '2016-06-24'] pickup_hour
# 0     14130.50
# 1      9091.50
# 2      5939.25
# 3      4051.25
# 4      3383.50
# 5      3798.50
# 6      8338.75
# 7     13974.25
# 8     17117.75
# 9     16000.00
# 10    14445.75
# 11    14557.75
# 12    15065.25
# 13    14747.50
# 14    15620.50
# 15    14060.50
# 16    12082.00
# 17    15336.50
# 18    18798.25
# 19    19513.25
# 20    17277.75
# 21    18387.50
# 22    19428.00
# 23    14896.50
# Name: trip_distance, dtype: float64
# Monday ['2016-06-06' '2016-06-13' '2016-06-20' '2016-06-27'] pickup_hour
# 0      7298.75
# 1      4589.50
# 2      3024.00
# 3      2056.50
# 4      2231.50
# 5      3438.75
# 6      8339.25
# 7     13192.25
# 8     15509.75
# 9     14803.50
# 10    13119.50
# 11    13179.50
# 12    13778.25
# 13    13839.50
# 14    15001.00
# 15    14391.00
# 16    13251.75
# 17    15776.75
# 18    18768.00
# 19    17767.00
# 20    16184.50
# 21    17819.50
# 22    15686.75
# 23     9583.50
# Name: trip_distance, dtype: float64
# Saturday ['2016-06-04' '2016-06-11' '2016-06-18' '2016-06-25'] pickup_hour
# 0     18281.25
# 1     15458.25
# 2     12539.50
# 3      9629.50
# 4      6307.50
# 5      3197.25
# 6      4031.50
# 7      6306.25
# 8      8579.50
# 9     11905.50
# 10    14010.00
# 11    15452.50
# 12    16370.00
# 13    16814.50
# 14    16038.50
# 15    15605.50
# 16    14258.50
# 17    16065.25
# 18    18040.50
# 19    18747.50
# 20    15969.75
# 21    16546.25
# 22    18321.25
# 23    14708.75
# Name: trip_distance, dtype: float64
# Sunday ['2016-06-05' '2016-06-12' '2016-06-19' '2016-06-26'] pickup_hour
# 0     18035.00
# 1     15583.00
# 2     12899.25
# 3      9907.75
# 4      6724.50
# 5      3082.50
# 6      3023.50
# 7      4343.00
# 8      6517.75
# 9      9464.25
# 10    12267.50
# 11    14808.50
# 12    14416.25
# 13    14187.75
# 14    14110.75
# 15    13346.50
# 16    12990.75
# 17    13682.75
# 18    15361.50
# 19    14374.00
# 20    12647.25
# 21    13048.75
# 22    12279.25
# 23     8839.75
# Name: trip_distance, dtype: float64
# Thursday ['2016-06-09' '2016-06-02' '2016-06-16' '2016-06-23' '2016-06-30'] pickup_hour
# 0     10555.0
# 1      6176.4
# 2      3738.0
# 3      2446.4
# 4      2304.6
# 5      3332.4
# 6      9037.2
# 7     14876.0
# 8     17304.2
# 9     16276.8
# 10    14755.2
# 11    14974.4
# 12    15446.4
# 13    15329.6
# 14    15806.6
# 15    14210.0
# 16    11833.2
# 17    14930.2
# 18    18623.6
# 19    19416.8
# 20    18191.4
# 21    20311.8
# 22    19279.0
# 23    13565.8
# Name: trip_distance, dtype: float64
# Tuesday ['2016-06-07' '2016-06-14' '2016-06-21' '2016-06-28'] pickup_hour
# 0      7746.00
# 1      4243.25
# 2      2535.25
# 3      1696.00
# 4      1770.25
# 5      3042.75
# 6      8565.00
# 7     14056.75
# 8     16615.50
# 9     15650.75
# 10    14339.25
# 11    14460.25
# 12    15096.25
# 13    14940.00
# 14    15543.25
# 15    14618.75
# 16    12600.00
# 17    15197.00
# 18    19188.75
# 19    18448.00
# 20    17051.75
# 21    18992.25
# 22    17597.75
# 23    11477.50
# Name: trip_distance, dtype: float64
# Wednesday ['2016-06-01' '2016-06-08' '2016-06-15' '2016-06-22' '2016-06-29'] pickup_hour
# 0      8865.0
# 1      5299.8
# 2      3109.0
# 3      2092.2
# 4      2051.2
# 5      3191.2
# 6      8391.2
# 7     14265.0
# 8     16983.6
# 9     16051.2
# 10    14542.4
# 11    15121.4
# 12    16054.2
# 13    15969.8
# 14    15718.8
# 15    14014.0
# 16    11633.8
# 17    14509.6
# 18    17984.4
# 19    18525.2
# 20    17642.6
# 21    19898.4
# 22    18586.2
# 23    12369.8
# Name: trip_distance, dtype: float64

# %%
test['pickup_hour'] = pd.to_datetime(test.tpep_pickup_datetime).dt.hour.astype('category')

# %%
test['day'] = (pd.to_datetime(test['tpep_pickup_datetime']).dt.weekday_name)

# %%
# %%time
test["ridesAtPickupHour"] = test.apply(lambda x: trafficPerDay[(trafficPerDay.day == x.day) & (trafficPerDay.pickup_hour==x.pickup_hour)].rides.iloc[0],axis=1 )
# Out:
# Wall time: 48.6 s

# %% [markdown]
# ## Remove some more outliers

# %%
t = train[train.avg_speed > 40]

# %%
t.describe()
# Out:
#        passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# count     21435.000000   21435.000000      21435.000000     21435.000000
# mean          1.655050      16.653108        -73.887584        40.707964
# std           1.311149       7.235212          0.096631         0.058282
# min           1.000000       0.370000        -74.913620        40.171890
# 25%           1.000000      13.340000        -73.981758        40.645973
# 50%           1.000000      17.130000        -73.883774        40.718315
# 75%           2.000000      19.310000        -73.783401        40.761063
# max           6.000000      99.960000        -73.212685        41.107155
#
#          RatecodeID  dropoff_longitude  dropoff_latitude  payment_type  \
# count  21435.000000       21435.000000      21435.000000  21435.000000
# mean       1.881969         -73.911413         40.719459      1.268300
# std        1.094520           0.151482          0.089660      0.491032
# min        1.000000         -74.984268         39.945095      1.000000
# 25%        1.000000         -73.987576         40.646820      1.000000
# 50%        2.000000         -73.926231         40.708008      1.000000
# 75%        2.000000         -73.788940         40.765629      1.000000
# max        5.000000         -73.017113         41.706463      4.000000
#
#         fare_amount         extra       mta_tax    tip_amount  tolls_amount  \
# count  21435.000000  21435.000000  21435.000000  21435.000000  21435.000000
# mean      51.418793      0.219827      0.435573      7.770273      3.517061
# std       28.728417      0.372911      0.167523      7.018051      4.773465
# min        3.000000      0.000000      0.000000      0.000000      0.000000
# 25%       39.000000      0.000000      0.500000      0.000000      0.000000
# 50%       52.000000      0.000000      0.500000      8.950000      0.000000
# 75%       52.000000      0.500000      0.500000     11.670000      5.540000
# max      400.000000      4.500000      0.500000    128.000000     30.000000
#
#        total_amount      duration      subtotal      tip_perc   pickup_hour  \
# count  21435.000000  21435.000000  21435.000000  21435.000000  21435.000000
# mean      63.661527   1372.414836     55.891254      0.135355      7.130721
# std       34.491467    579.544965     30.633138      0.108620      7.050564
# min        3.300000     30.000000      3.300000      0.000000      0.000000
# 25%       43.800000   1099.000000     40.300000      0.000000      2.000000
# 50%       65.300000   1419.000000     56.300000      0.199691      5.000000
# 75%       70.010000   1617.000000     58.340000      0.200034      9.000000
# max      483.340000   7755.000000    418.340000      3.703704     23.000000
#
#           avg_speed  ridesAtPickupHour
# count  21435.000000       21435.000000
# mean      44.053253       34690.734686
# std        4.354260       23022.912625
# min       40.000000        6784.000000
# 25%       41.267221       15194.000000
# 50%       42.933516       29195.000000
# 75%       45.439425       52775.000000
# max       80.000000      101559.000000

# %%
t.RatecodeID.value_counts()
# Out:
# 1    9475
# 2    8346
# 3    1730
# 5    1447
# 4     437
# Name: RatecodeID, dtype: int64

# %%
train.RatecodeID.value_counts()
# Out:
# 1    8907479
# 2     127432
# 3      17425
# 5      11165
# 4       3539
# Name: RatecodeID, dtype: int64

# %%
train = train[(train.trip_distance <= 50) & (train.avg_speed<=60)]

# %%
train.shape
# Out:
# (9066597, 27)

# %%
test.describe()
# Out:
#                  id      VendorID  passenger_count  trip_distance  \
# count  64000.000000  64000.000000     64000.000000   64000.000000
# mean   32000.500000      1.537047         1.671188       5.896713
# std    18475.352951      0.498630         1.303686       7.234262
# min        1.000000      1.000000         0.000000       0.010000
# 25%    16000.750000      1.000000         1.000000       1.200000
# 50%    32000.500000      2.000000         1.000000       2.260000
# 75%    48000.250000      2.000000         2.000000       8.080000
# max    64000.000000      2.000000         9.000000      86.600000
#
#        pickup_longitude  pickup_latitude    RatecodeID  dropoff_longitude  \
# count      64000.000000     64000.000000  64000.000000       64000.000000
# mean         -73.960769        40.744481      1.406250         -73.975568
# std            0.060701         0.037676      0.913769           0.084823
# min          -74.527763        40.535580      1.000000         -74.833679
# 25%          -73.991264        40.732536      1.000000         -73.993828
# 50%          -73.980370        40.752197      1.000000         -73.980309
# 75%          -73.962111        40.766815      1.000000         -73.960541
# max          -72.659561        41.255787      5.000000         -72.551582
#
#        dropoff_latitude  payment_type  tolls_amount  improvement_surcharge  \
# count      64000.000000  64000.000000   64000.00000           64000.000000
# mean          40.746855      1.337031       1.74787               0.299991
# std            0.047903      0.492926       4.14628               0.001677
# min           40.045311      1.000000       0.00000               0.000000
# 25%           40.725780      1.000000       0.00000               0.300000
# 50%           40.751484      1.000000       0.00000               0.300000
# 75%           40.768697      2.000000       0.00000               0.300000
# max           41.525589      4.000000      82.50000               0.300000
#
#            duration     avg_speed  ridesAtPickupHour
# count  64000.000000  64000.000000       64000.000000
# mean    1230.515344     14.546904       14415.856201
# std     1080.955692      9.388043        3799.740583
# min       40.000000      0.014337        1696.000000
# 25%      468.000000      8.153310       13251.750000
# 50%      858.000000     11.716077       14940.000000
# 75%     1659.000000     18.140034       16814.500000
# max     9931.000000    176.170213       20311.800000

# %% [markdown]
# ## Function for parameter optimization for lightGBM

# %%
#optimization parameters for lightGBM
param_grid = {    
    'num_leaves':[7,31,150,500],
    #"max_depth":[-1,10,30,51],
    'learning_rate': [0.003],  
    "objective": ["mae"],
    "bagging_fraction" : [0.8], 
    "feature_fraction" : [0.8],
    "num_threads" : [4],
    "verbose":[-1],
    "boosting":["gbdt"], #rf does not work
}

# %%
from sklearn.model_selection import ParameterGrid
from operator import itemgetter
import lightgbm as lgb
import timeit
import copy

def optimisedLGM(param_grid,trainData,labels,stopping=50):
    lgb_dataset = lgb.Dataset(trainData, label=labels)


    cv_results = []
    counter = 0
    print("Total parameter combinations to run:",len(ParameterGrid(param_grid)))
    first_param = None;
    for params in ParameterGrid(param_grid):
        start_time = timeit.default_timer()
        counter=counter+1
        print("Starting run",counter)
        print(params)
        validation_summary = lgb.cv(params,
                                    lgb_dataset,
                                    num_boost_round=10000, 
                                    nfold=3,
                                    early_stopping_rounds=stopping,
                                    verbose_eval=100,
                                    stratified=False)

        params["optimal_number_of_trees"] = len(validation_summary["l1-mean"])
        if(first_param == None):
            first_param=copy.deepcopy(params)
        cv_results.append((params, validation_summary["l1-mean"][-1]))    
        #this currently is buggy. the first element of the results will always be overriden by the last
        
        elapsed = timeit.default_timer() - start_time
        if (counter %1 == 0):
            print("Run done, took:",round(elapsed,2),"s")   

    first_tuple = cv_results[0]
    first_param
    cv_results[0] = (first_param,first_tuple[1]) # this fixes the bug mentioned above, no idea why this is happening though
    param_set = min(cv_results,key=itemgetter(1)) #best params, minimal mae
    print("Best params:",param_set)
    #print(cv_results)   
    lgb_model = lgb.train(param_set[0],lgb_dataset,param_set[0]["optimal_number_of_trees"])
    return lgb_model

# %%
from sklearn.model_selection import ParameterGrid
from operator import itemgetter
import lightgbm as lgb
import timeit
from sklearn.model_selection import GridSearchCV

def optimisedLGM2(param_grid,trainData,labels):

    estimator = lgb.LGBMRegressor(objective = "mae",n_jobs=2)
    param_grid = {
        'learning_rate': [0.05],
        'n_estimators': [200,400,600,800],
        'num_leaves':[7,80],
        "boosting_type":["gbdt"],
        "max_depth":[2,63,None],    
    }

    gbm = GridSearchCV(estimator,param_grid,verbose=2,n_jobs=2)    

    gbm.fit(trainData,labels)
    print('Best parameters found by grid search are:', gbm.best_params_)
    print("Best score:",gbm.cv_results_)
    return gbm;

# %% [markdown]
# # Ratecode 1 (Standard rate)

# %% [markdown]
# ## Building the Model

# %%
code1data = train[train.RatecodeID == 1]

# %%
code1test = test[test.RatecodeID == 1]

# %%
# %%time
features = ["duration","trip_distance","avg_speed","ridesAtPickupHour"]
#train new model
#code1_model = optimisedLGM(param_grid,code1data[features],code1data["fare_amount"])

#use old params
params = ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 3000})
code1_dataset = lgb.Dataset(code1data[features], label=code1data["fare_amount"])
code1_model = lgb.train(params,code1_dataset,params["optimal_number_of_trees"])
# Out:
# Wall time: 14min 19s

# %% [markdown]
# ## Prediction

# %%
code1prediction = np.round(code1_model.predict(code1test[features])*2)/2

# %%
code1prediction
# Out:
# array([ 4. ,  6.5, 10.5, ...,  4.5,  6. , 15.5])

# %%
code1test = code1test.assign(fare_amount_prediction = code1prediction)

# %% [markdown]
# # Ratecode 2 (JFK)

# %% [markdown]
# ## Building the Model

# %% [markdown]
# No model building neccessary, all rides cost 52$

# %%
code2data = train[train.RatecodeID == 2]
code2test = test[test.RatecodeID == 2]

# %% [markdown]
# ## Prediction

# %%
code2test["fare_amount_prediction"] = 52.0

# %% [markdown]
# # Ratecode 3 (Newark)

# %% [markdown]
# ## Building the Model

# %%
code3data = train[train.RatecodeID == 3]

# %%
code3test = test[test.RatecodeID == 3]

# %%
# %%time
features = ["duration","trip_distance","avg_speed","ridesAtPickupHour"]
code3_model = optimisedLGM(param_grid,code3data[features],code3data["fare_amount"])
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 6.33149 + 0.0814524
# [200]	cv_agg's l1: 5.43691 + 0.0804796
# [300]	cv_agg's l1: 4.73468 + 0.0818108
# [400]	cv_agg's l1: 4.1602 + 0.0903564
# [500]	cv_agg's l1: 3.68588 + 0.0884908
# [600]	cv_agg's l1: 3.28558 + 0.072269
# [700]	cv_agg's l1: 2.96031 + 0.0710726
# [800]	cv_agg's l1: 2.67569 + 0.0701165
# [900]	cv_agg's l1: 2.43307 + 0.0737765
# [1000]	cv_agg's l1: 2.23937 + 0.0701904
# [1100]	cv_agg's l1: 2.03351 + 0.0763275
# [1200]	cv_agg's l1: 1.78433 + 0.0856294
# [1300]	cv_agg's l1: 1.55291 + 0.0704166
# [1400]	cv_agg's l1: 1.37917 + 0.0541589
# [1500]	cv_agg's l1: 1.25084 + 0.0405391
# [1600]	cv_agg's l1: 1.15727 + 0.031139
# [1700]	cv_agg's l1: 1.08871 + 0.025984
# [1800]	cv_agg's l1: 1.03801 + 0.0229524
# [1900]	cv_agg's l1: 1.00026 + 0.0197828
# [2000]	cv_agg's l1: 0.972173 + 0.0176617
# [2100]	cv_agg's l1: 0.9508 + 0.0160224
# [2200]	cv_agg's l1: 0.934401 + 0.0148379
# [2300]	cv_agg's l1: 0.921301 + 0.0132822
# [2400]	cv_agg's l1: 0.911751 + 0.0118215
# [2500]	cv_agg's l1: 0.903797 + 0.0112576
# [2600]	cv_agg's l1: 0.897494 + 0.00975265
# [2700]	cv_agg's l1: 0.892755 + 0.00902595
# [2800]	cv_agg's l1: 0.888984 + 0.00857778
# [2900]	cv_agg's l1: 0.886034 + 0.00825694
# [3000]	cv_agg's l1: 0.883368 + 0.00769318
# [3100]	cv_agg's l1: 0.881252 + 0.00744758
# [3200]	cv_agg's l1: 0.879254 + 0.00732823
# [3300]	cv_agg's l1: 0.877341 + 0.00737509
# [3400]	cv_agg's l1: 0.875635 + 0.00750937
# [3500]	cv_agg's l1: 0.874247 + 0.00786654
# [3600]	cv_agg's l1: 0.872636 + 0.00818024
# [3700]	cv_agg's l1: 0.871215 + 0.00820952
# [3800]	cv_agg's l1: 0.869917 + 0.0081818
# [3900]	cv_agg's l1: 0.868307 + 0.0081739
# [4000]	cv_agg's l1: 0.867051 + 0.00813231
# [4100]	cv_agg's l1: 0.865766 + 0.00786201
# [4200]	cv_agg's l1: 0.864913 + 0.00794673
# [4300]	cv_agg's l1: 0.863049 + 0.00740181
# [4400]	cv_agg's l1: 0.861266 + 0.00685233
# [4500]	cv_agg's l1: 0.859499 + 0.00638896
# [4600]	cv_agg's l1: 0.858391 + 0.0065575
# [4700]	cv_agg's l1: 0.856808 + 0.00649801
# [4800]	cv_agg's l1: 0.855254 + 0.00674616
# [4900]	cv_agg's l1: 0.853803 + 0.00637479
# [5000]	cv_agg's l1: 0.852222 + 0.00596322
# [5100]	cv_agg's l1: 0.850632 + 0.00546865
# [5200]	cv_agg's l1: 0.849299 + 0.0053789
# [5300]	cv_agg's l1: 0.847927 + 0.00517858
# [5400]	cv_agg's l1: 0.846848 + 0.00511962
# [5500]	cv_agg's l1: 0.845638 + 0.00509421
# [5600]	cv_agg's l1: 0.844596 + 0.00478572
# [5700]	cv_agg's l1: 0.843727 + 0.00477654
# [5800]	cv_agg's l1: 0.84294 + 0.00484422
# [5900]	cv_agg's l1: 0.842 + 0.00479282
# [6000]	cv_agg's l1: 0.841234 + 0.0048288
# [6100]	cv_agg's l1: 0.84051 + 0.00484198
# [6200]	cv_agg's l1: 0.839614 + 0.00495369
# [6300]	cv_agg's l1: 0.838634 + 0.00498273
# [6400]	cv_agg's l1: 0.837655 + 0.00494394
# [6500]	cv_agg's l1: 0.837131 + 0.00512349
# [6600]	cv_agg's l1: 0.836478 + 0.00510611
# [6700]	cv_agg's l1: 0.835922 + 0.00519186
# [6800]	cv_agg's l1: 0.835132 + 0.00517646
# [6900]	cv_agg's l1: 0.834523 + 0.0051984
# [7000]	cv_agg's l1: 0.833862 + 0.00525872
# [7100]	cv_agg's l1: 0.833161 + 0.00529562
# [7200]	cv_agg's l1: 0.832547 + 0.00539281
# [7300]	cv_agg's l1: 0.831609 + 0.00558601
# [7400]	cv_agg's l1: 0.830912 + 0.00579017
# [7500]	cv_agg's l1: 0.830185 + 0.00598627
# [7600]	cv_agg's l1: 0.829611 + 0.00605255
# [7700]	cv_agg's l1: 0.828893 + 0.00614828
# [7800]	cv_agg's l1: 0.8283 + 0.00617088
# [7900]	cv_agg's l1: 0.827742 + 0.00615206
# [8000]	cv_agg's l1: 0.827261 + 0.00614694
# [8100]	cv_agg's l1: 0.826665 + 0.00637503
# [8200]	cv_agg's l1: 0.826085 + 0.00654783
# [8300]	cv_agg's l1: 0.825544 + 0.0068201
# [8400]	cv_agg's l1: 0.825015 + 0.00701898
# [8500]	cv_agg's l1: 0.824536 + 0.00709963
# [8600]	cv_agg's l1: 0.824138 + 0.00714997
# [8700]	cv_agg's l1: 0.823702 + 0.00714108
# [8800]	cv_agg's l1: 0.823276 + 0.00720694
# [8900]	cv_agg's l1: 0.822972 + 0.00721888
# [9000]	cv_agg's l1: 0.822635 + 0.00737416
# [9100]	cv_agg's l1: 0.822355 + 0.00732296
# [9200]	cv_agg's l1: 0.821996 + 0.00752244
# [9300]	cv_agg's l1: 0.821472 + 0.00753582
# [9400]	cv_agg's l1: 0.821189 + 0.00755558
# [9500]	cv_agg's l1: 0.820868 + 0.00749921
# [9600]	cv_agg's l1: 0.820464 + 0.0075646
# [9700]	cv_agg's l1: 0.819869 + 0.00744132
# [9800]	cv_agg's l1: 0.819447 + 0.00750116
# [9900]	cv_agg's l1: 0.81903 + 0.00774776
# [10000]	cv_agg's l1: 0.818698 + 0.00780758
# Run done, took: 10.77 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 6.04944 + 0.0865537
# [200]	cv_agg's l1: 4.93544 + 0.0883569
# [300]	cv_agg's l1: 4.07162 + 0.0972007
# [400]	cv_agg's l1: 3.39564 + 0.0903983
# [500]	cv_agg's l1: 2.86799 + 0.0835234
# [600]	cv_agg's l1: 2.45125 + 0.0768597
# [700]	cv_agg's l1: 2.11172 + 0.0654053
# [800]	cv_agg's l1: 1.84553 + 0.0581661
# [900]	cv_agg's l1: 1.63037 + 0.0536324
# [1000]	cv_agg's l1: 1.4419 + 0.0456294
# [1100]	cv_agg's l1: 1.27754 + 0.0362198
# [1200]	cv_agg's l1: 1.16079 + 0.0265917
# [1300]	cv_agg's l1: 1.07559 + 0.0222895
# [1400]	cv_agg's l1: 1.0151 + 0.0205102
# [1500]	cv_agg's l1: 0.97113 + 0.0193442
# [1600]	cv_agg's l1: 0.938429 + 0.0172342
# [1700]	cv_agg's l1: 0.914166 + 0.0153394
# [1800]	cv_agg's l1: 0.896411 + 0.0136556
# [1900]	cv_agg's l1: 0.882892 + 0.012543
# [2000]	cv_agg's l1: 0.871539 + 0.0119922
# [2100]	cv_agg's l1: 0.862287 + 0.0110285
# [2200]	cv_agg's l1: 0.855095 + 0.0106394
# [2300]	cv_agg's l1: 0.848368 + 0.0100616
# [2400]	cv_agg's l1: 0.842756 + 0.00984953
# [2500]	cv_agg's l1: 0.837977 + 0.0107476
# [2600]	cv_agg's l1: 0.83323 + 0.0108695
# [2700]	cv_agg's l1: 0.829586 + 0.0108909
# [2800]	cv_agg's l1: 0.826289 + 0.0109935
# [2900]	cv_agg's l1: 0.823746 + 0.0115608
# [3000]	cv_agg's l1: 0.821527 + 0.0120803
# [3100]	cv_agg's l1: 0.819805 + 0.0123513
# [3200]	cv_agg's l1: 0.81844 + 0.0125252
# [3300]	cv_agg's l1: 0.816971 + 0.0124081
# [3400]	cv_agg's l1: 0.815712 + 0.0121534
# [3500]	cv_agg's l1: 0.814744 + 0.0118267
# [3600]	cv_agg's l1: 0.813302 + 0.0110176
# [3700]	cv_agg's l1: 0.812417 + 0.0106656
# [3800]	cv_agg's l1: 0.811175 + 0.0103065
# [3900]	cv_agg's l1: 0.810085 + 0.00976692
# [4000]	cv_agg's l1: 0.809417 + 0.00959378
# [4100]	cv_agg's l1: 0.808739 + 0.00942713
# [4200]	cv_agg's l1: 0.808151 + 0.0094737
# [4300]	cv_agg's l1: 0.807638 + 0.00941711
# [4400]	cv_agg's l1: 0.807225 + 0.00942423
# [4500]	cv_agg's l1: 0.806833 + 0.00934477
# [4600]	cv_agg's l1: 0.806371 + 0.00920743
# [4700]	cv_agg's l1: 0.805896 + 0.00891416
# [4800]	cv_agg's l1: 0.805354 + 0.00853451
# [4900]	cv_agg's l1: 0.804822 + 0.00799797
# [5000]	cv_agg's l1: 0.804446 + 0.00755886
# [5100]	cv_agg's l1: 0.80413 + 0.0071958
# [5200]	cv_agg's l1: 0.803832 + 0.00684576
# [5300]	cv_agg's l1: 0.803617 + 0.00675259
# [5400]	cv_agg's l1: 0.803233 + 0.00647465
# [5500]	cv_agg's l1: 0.802976 + 0.00635928
# [5600]	cv_agg's l1: 0.802729 + 0.00618202
# [5700]	cv_agg's l1: 0.80246 + 0.00581514
# [5800]	cv_agg's l1: 0.802232 + 0.00566158
# [5900]	cv_agg's l1: 0.802038 + 0.00558859
# [6000]	cv_agg's l1: 0.801883 + 0.0055991
# [6100]	cv_agg's l1: 0.801666 + 0.0056078
# [6200]	cv_agg's l1: 0.801407 + 0.00555838
# [6300]	cv_agg's l1: 0.801159 + 0.00557993
# [6400]	cv_agg's l1: 0.800894 + 0.00554188
# [6500]	cv_agg's l1: 0.800666 + 0.00547421
# [6600]	cv_agg's l1: 0.800505 + 0.0053787
# [6700]	cv_agg's l1: 0.800327 + 0.00527686
# [6800]	cv_agg's l1: 0.800182 + 0.00529028
# [6900]	cv_agg's l1: 0.800115 + 0.00532506
# [7000]	cv_agg's l1: 0.799956 + 0.00528694
# [7100]	cv_agg's l1: 0.799857 + 0.00531485
# [7200]	cv_agg's l1: 0.79967 + 0.00535383
# [7300]	cv_agg's l1: 0.799545 + 0.00538282
# [7400]	cv_agg's l1: 0.799482 + 0.0053833
# [7500]	cv_agg's l1: 0.799374 + 0.00536788
# [7600]	cv_agg's l1: 0.799237 + 0.0053411
# [7700]	cv_agg's l1: 0.799104 + 0.00530399
# [7800]	cv_agg's l1: 0.798999 + 0.00523211
# [7900]	cv_agg's l1: 0.798954 + 0.00518077
# [8000]	cv_agg's l1: 0.798813 + 0.00510763
# [8100]	cv_agg's l1: 0.798686 + 0.00503366
# [8200]	cv_agg's l1: 0.798552 + 0.00497065
# [8300]	cv_agg's l1: 0.798502 + 0.00492719
# [8400]	cv_agg's l1: 0.798465 + 0.00488071
# [8500]	cv_agg's l1: 0.798425 + 0.00485693
# [8600]	cv_agg's l1: 0.798346 + 0.00486583
# [8700]	cv_agg's l1: 0.79833 + 0.00486072
# [8800]	cv_agg's l1: 0.798237 + 0.00474003
# [8900]	cv_agg's l1: 0.798183 + 0.0047412
# [9000]	cv_agg's l1: 0.798149 + 0.00473382
# [9100]	cv_agg's l1: 0.798079 + 0.00471032
# [9200]	cv_agg's l1: 0.797944 + 0.00455623
# [9300]	cv_agg's l1: 0.797826 + 0.0044573
# [9400]	cv_agg's l1: 0.797762 + 0.00441664
# [9500]	cv_agg's l1: 0.79773 + 0.00437697
# [9600]	cv_agg's l1: 0.797677 + 0.00436901
# [9700]	cv_agg's l1: 0.797653 + 0.00440085
# [9800]	cv_agg's l1: 0.797523 + 0.00436274
# [9900]	cv_agg's l1: 0.797478 + 0.00434663
# Run done, took: 19.74 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.96277 + 0.0814603
# [200]	cv_agg's l1: 4.79809 + 0.0888737
# [300]	cv_agg's l1: 3.90387 + 0.0841453
# [400]	cv_agg's l1: 3.21529 + 0.0727497
# [500]	cv_agg's l1: 2.67725 + 0.0633202
# [600]	cv_agg's l1: 2.25768 + 0.0511212
# [700]	cv_agg's l1: 1.93027 + 0.0437246
# [800]	cv_agg's l1: 1.66818 + 0.0347439
# [900]	cv_agg's l1: 1.44521 + 0.0317682
# [1000]	cv_agg's l1: 1.26976 + 0.0237346
# [1100]	cv_agg's l1: 1.14452 + 0.0196779
# [1200]	cv_agg's l1: 1.05721 + 0.0175831
# [1300]	cv_agg's l1: 0.99572 + 0.0161332
# [1400]	cv_agg's l1: 0.952877 + 0.0152294
# [1500]	cv_agg's l1: 0.921777 + 0.0135104
# [1600]	cv_agg's l1: 0.89958 + 0.0119256
# [1700]	cv_agg's l1: 0.883135 + 0.0108974
# [1800]	cv_agg's l1: 0.869874 + 0.0107619
# [1900]	cv_agg's l1: 0.859164 + 0.0103531
# [2000]	cv_agg's l1: 0.85101 + 0.00964913
# [2100]	cv_agg's l1: 0.84481 + 0.00880081
# [2200]	cv_agg's l1: 0.838724 + 0.00834687
# [2300]	cv_agg's l1: 0.833392 + 0.00914584
# [2400]	cv_agg's l1: 0.829422 + 0.00949575
# [2500]	cv_agg's l1: 0.825839 + 0.00980788
# [2600]	cv_agg's l1: 0.822619 + 0.00998776
# [2700]	cv_agg's l1: 0.820516 + 0.00991828
# [2800]	cv_agg's l1: 0.818627 + 0.00944033
# [2900]	cv_agg's l1: 0.816666 + 0.00854044
# [3000]	cv_agg's l1: 0.815202 + 0.00833969
# [3100]	cv_agg's l1: 0.81369 + 0.00805415
# [3200]	cv_agg's l1: 0.812217 + 0.00744454
# [3300]	cv_agg's l1: 0.810897 + 0.0069859
# [3400]	cv_agg's l1: 0.809842 + 0.00634144
# [3500]	cv_agg's l1: 0.809325 + 0.00611547
# [3600]	cv_agg's l1: 0.808788 + 0.00585392
# [3700]	cv_agg's l1: 0.808335 + 0.00553013
# [3800]	cv_agg's l1: 0.807982 + 0.00539038
# [3900]	cv_agg's l1: 0.807501 + 0.00512461
# [4000]	cv_agg's l1: 0.807081 + 0.00481217
# [4100]	cv_agg's l1: 0.80672 + 0.00445368
# [4200]	cv_agg's l1: 0.806579 + 0.00427598
# [4300]	cv_agg's l1: 0.806385 + 0.00396773
# [4400]	cv_agg's l1: 0.806228 + 0.00376664
# [4500]	cv_agg's l1: 0.806141 + 0.00366231
# [4600]	cv_agg's l1: 0.80608 + 0.00352891
# [4700]	cv_agg's l1: 0.806031 + 0.00342528
# Run done, took: 26.02 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.96047 + 0.0809029
# [200]	cv_agg's l1: 4.76135 + 0.0809213
# [300]	cv_agg's l1: 3.83935 + 0.0703223
# [400]	cv_agg's l1: 3.12509 + 0.0552055
# [500]	cv_agg's l1: 2.5641 + 0.0420647
# [600]	cv_agg's l1: 2.13924 + 0.0367315
# [700]	cv_agg's l1: 1.8074 + 0.0336843
# [800]	cv_agg's l1: 1.53105 + 0.0317402
# [900]	cv_agg's l1: 1.32226 + 0.023518
# [1000]	cv_agg's l1: 1.17924 + 0.0182349
# [1100]	cv_agg's l1: 1.08137 + 0.017113
# [1200]	cv_agg's l1: 1.01354 + 0.0159296
# [1300]	cv_agg's l1: 0.965779 + 0.0152613
# [1400]	cv_agg's l1: 0.931875 + 0.0142934
# [1500]	cv_agg's l1: 0.908313 + 0.0127507
# [1600]	cv_agg's l1: 0.890716 + 0.0116779
# [1700]	cv_agg's l1: 0.877828 + 0.0109991
# [1800]	cv_agg's l1: 0.868758 + 0.0100631
# [1900]	cv_agg's l1: 0.8606 + 0.0100665
# [2000]	cv_agg's l1: 0.854104 + 0.00891171
# [2100]	cv_agg's l1: 0.847512 + 0.00886904
# [2200]	cv_agg's l1: 0.841768 + 0.00845634
# [2300]	cv_agg's l1: 0.837868 + 0.00821337
# [2400]	cv_agg's l1: 0.834707 + 0.00798471
# [2500]	cv_agg's l1: 0.832139 + 0.00739113
# [2600]	cv_agg's l1: 0.830302 + 0.00702645
# [2700]	cv_agg's l1: 0.829044 + 0.00672489
# [2800]	cv_agg's l1: 0.827888 + 0.00607892
# [2900]	cv_agg's l1: 0.826826 + 0.00552929
# [3000]	cv_agg's l1: 0.825982 + 0.00507782
# [3100]	cv_agg's l1: 0.825104 + 0.00456444
# [3200]	cv_agg's l1: 0.824637 + 0.00445539
# [3300]	cv_agg's l1: 0.824141 + 0.00434641
# [3400]	cv_agg's l1: 0.823858 + 0.0042091
# [3500]	cv_agg's l1: 0.82356 + 0.00403562
# [3600]	cv_agg's l1: 0.823495 + 0.00400686
# [3700]	cv_agg's l1: 0.823386 + 0.0039548
# Run done, took: 48.86 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 9892}, 0.7974754905195738)
# Wall time: 1min 51s

# %% [markdown]
# ## Prediction

# %%
code3prediction = np.round(code3_model.predict(code3test[features])*2)/2
code3test = code3test.assign(fare_amount_prediction = code3prediction)

# %% [markdown]
# # Ratecode 4 (Nassau or Westchester)

# %% [markdown]
# ## Building the Model

# %%
code4data = train[train.RatecodeID == 4]
code4test = test[test.RatecodeID == 4]
np.shape(code4test)
# Out:
# (1000, 20)

# %%
#shapely can be installed via anaconda -> environments
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
# returns whether the point given is in the area given
def inArea(polygon,lat,long):
    point = Point(lat,long);
    poly = Polygon(polygon)
    return poly.contains(point)

# %%
#cords for a polygon around manhatten, manually set via google maps
manhattan_cords = [(40.882207, -73.933869), #1
         (40.872343, -73.908292), #2
         (40.836117, -73.933011), #3
         (40.804680, -73.931123), #4
         (40.798833, -73.918591), #5
         (40.739289, -73.967000), #6
         (40.707155, -73.973866), #7
         (40.699217, -74.021416), #8
         (40.759316, -74.012662)] #9

# %%
#apply to train set
code4data["endsInManhattan"] = code4data.apply(lambda x : inArea(manhattan_cords,x["dropoff_latitude"],x["dropoff_longitude"]),axis=1)
code4data["startsInManhattan"] = code4data.apply(lambda x : inArea(manhattan_cords,x["pickup_latitude"],x["pickup_longitude"]),axis=1)

# %%
from geopy.distance import geodesic
from geopy.distance import great_circle

# %%
#calculate air line distance for train data set
code4data["airlineDistance"] = code4data.apply(lambda x: geodesic((x["pickup_latitude"],x["pickup_longitude"]),
                                                                  (x["dropoff_latitude"],x["dropoff_longitude"])).miles,axis=1)

# %%
code4data.airlineDistance.describe()
# Out:
# count    3539.000000
# mean        9.828547
# std         5.326620
# min         0.012965
# 25%         5.275523
# 50%         9.864279
# 75%        13.461053
# max        27.942278
# Name: airlineDistance, dtype: float64

# %%
np.shape(code4data[["airlineDistance","trip_distance"]])
# Out:
# (3539, 2)

# %%
np.shape(code4data[code4data.trip_distance<code4data.airlineDistance])
# Out:
# (45, 30)

# %%
ax = sns.regplot(code4data.trip_distance,code4data.airlineDistance)
ax.plot([0,0],[40,40], linewidth=2,color="red")

# %%
# all bridges and tunnels to/from manhattan, bridges marked with ! are highways or tunnels and more likely to be used by taxis
bridges = [ (40.877720, -73.922362), # 0 henry hudson bridge !
          (40.873648, -73.911075), # 1 broadway !
          (40.862840, -73.914986), # 2 university heights bridge
          (40.846674, -73.927806), # 3 washington bridge - close to v
          (40.845522, -73.928256), # 4 alexander hamilton bridge !
          (40.828062, -73.933873), # 5 macombs dam bridge
          (40.819489, -73.933058), # 6 145th st bridge - close to v
          (40.814081, -73.933187), # 7 madison avenue bridge
          (40.807591, -73.932399), # 8 third avenue bridge
           (40.803516, -73.928818),# 9 willis ave bridge
           (40.800368, -73.927835), # 10 robert f kennedy bridge !
           (40.756681, -73.954185), # 11 ed koch queensboro bridge !
           (40.745106, -73.964063), # 12 queens midtown tunnel !
           (40.713407, -73.972299), # 13 williamsburg bridge
           (40.707095, -73.990500), # 14 manhattan bridge
           (40.705972, -73.996851), # 15 brooklyn bridge !
           (40.701161, -74.015692), # 16 Hugh l Carey Tunnel
           (40.727487, -74.020880), # 17 holland tunnel
           (40.763370, -74.010028), # 18 lincoln tunnel !
           (40.851644, -73.952118), # 19 george washington bridge !
          ]

# %%
# try to find out which bridge is used in a trip 
# assumption: the bridge is used that minimizes the pickup-bridge-dropoff distance (air-line distance)
counter = 1
for index, row in code4data.iterrows():
    # 4 options:
    # starts in city, ends in city --> should not have ratecode 4 -> outlier, ignore
    # starts in city, ends out of city -> standard trip
    # starts out of city, ends out of city -> no calculations to be done here, use double rate for whole trip
    # starts out of city, ends in city -> reverse standard trip
    startP = (row["pickup_latitude"],row["pickup_longitude"])
    endP = (row["dropoff_latitude"],row["dropoff_longitude"])
    
    if(row.startsInManhattan and row.endsInManhattan):
        #print("Outlier found, index",index)
        continue
    elif (not row.startsInManhattan and not row.endsInManhattan):
        #print("Complete out of city trip, index",index)
        code4data.at[index,"Bridge"] = None;
        code4data.at[index,"in_city_distance"] = 0;
        code4data.at[index,"out_of_city_distance"] = geodesic(startP, endP).miles
        code4data.at[index,"total_over_bridge_distance"] = geodesic(startP, endP).miles  
        continue
    elif (not row.startsInManhattan and  row.endsInManhattan): # reverse trip
        temp = startP # here we swap start and endpoints so its similar to a standard trip
        startP = endP
        endP = temp
    
    #find closest bridge
    closest_bridge_index = -1
    closest_total_bridge_distance = float('inf')
    for i in range(len(bridges)):
        distance_to_bridge = geodesic(startP, bridges[i]).miles
        distance_to_dest =  geodesic(bridges[i],endP).miles
        total = distance_to_bridge + distance_to_dest
        if(total < closest_total_bridge_distance):
            closest_total_bridge_distance = total
            closest_bridge_index = i
            closest_distance_to_bridge = distance_to_bridge
            closest_distance_to_dest = distance_to_dest
            
    #print("Route {} travels over bridge/tunnel {} (to bridge: {:0.2f}, to dest: {:0.2f}, total: {:0.2f}, trip_distance : {:0.2f})".format(
    #    counter, closest_bridge_index,closest_distance_to_bridge,closest_distance_to_dest,closest_total_bridge_distance,totalDistance))
    counter = counter + 1
    
    code4data.at[index,"Bridge"] = closest_bridge_index;
    code4data.at[index,"in_city_distance"] = closest_distance_to_bridge;
    code4data.at[index,"out_of_city_distance"] = closest_distance_to_dest
    code4data.at[index,"total_over_bridge_distance"] = closest_total_bridge_distance

# %%
#states how much of the fare was contributed by ride in the city. Calculated by 
code4data["inCityPercentage"] = code4data.apply(lambda x: x.in_city_distance/(x.in_city_distance+2*x.out_of_city_distance+0.0001),axis=1)

# %%
#2.5 were subtracted from fare amount (inital charge)
code4data["inCityFare"] = code4data.apply(lambda x: x.inCityPercentage*(x.fare_amount-2.5),axis=1)
code4data["outCityFare"] = code4data.apply(lambda x: (1-x.inCityPercentage)*(x.fare_amount-2.5),axis=1)

# %%
code4data["inCityTripDistanceExtreme"] = code4data.apply(lambda x: x.inCityPercentage*x.trip_distance,axis=1)
code4data["outCityTripDistanceExtreme"] = code4data.apply(lambda x: (1-x.inCityPercentage)*x.trip_distance,axis=1)

# %%
code4data["inCityTripDistance"] = code4data.apply(lambda x: x.in_city_distance/(x.in_city_distance+x.out_of_city_distance),axis=1)
code4data["outCityTripDistance"] = code4data.apply(lambda x: x.out_of_city_distance/(x.in_city_distance+x.out_of_city_distance),axis=1)

# %% [markdown]
# Now we have to train three models. Two for trips that start in the city and end out of it and vice versa, thus using both the standard and the doubled rate (one model for each). The predctions are then add up. The third model is for trips that are completly out of the city and therefore only use the doubled rate. Here more information can be used from the dataset, because we do not have to make assumptions on where the trip was split.

# %%
code4data_mixed = code4data[code4data.startsInManhattan ^ code4data.endsInManhattan] # trips that used a bridge -> entered/left manhattan
np.shape(code4data_mixed)
# Out:
# (602, 41)

# %%
code4data_out = code4data[(code4data.startsInManhattan==False) & (code4data.endsInManhattan==False)] # trips that not used a bridge -> never were in Manhattan
np.shape(code4data_out)
# Out:
# (2768, 41)

# %%
# %%time
#chose features
features_inner = ["inCityTripDistance","trip_distance","duration","ridesAtPickupHour","avg_speed"]
features_outer = ["outCityTripDistance","trip_distance","duration","ridesAtPickupHour","avg_speed"]

mixed_inner_train = code4data_mixed[features_inner]
mixed_outer_train = code4data_mixed[features_outer]

code4_model_inner = optimisedLGM(param_grid,mixed_inner_train,code4data_mixed["inCityFare"])
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.01997 + 0.195987
# [200]	cv_agg's l1: 4.31246 + 0.196619
# [300]	cv_agg's l1: 3.74391 + 0.203808
# [400]	cv_agg's l1: 3.27712 + 0.251358
# [500]	cv_agg's l1: 2.91087 + 0.289094
# [600]	cv_agg's l1: 2.59329 + 0.311678
# [700]	cv_agg's l1: 2.35564 + 0.310112
# [800]	cv_agg's l1: 2.14742 + 0.285596
# [900]	cv_agg's l1: 1.9855 + 0.24542
# [1000]	cv_agg's l1: 1.8554 + 0.225682
# [1100]	cv_agg's l1: 1.7458 + 0.20795
# [1200]	cv_agg's l1: 1.65932 + 0.193193
# [1300]	cv_agg's l1: 1.59222 + 0.184975
# [1400]	cv_agg's l1: 1.54748 + 0.178832
# [1500]	cv_agg's l1: 1.49627 + 0.158895
# [1600]	cv_agg's l1: 1.44868 + 0.130961
# [1700]	cv_agg's l1: 1.41239 + 0.116241
# [1800]	cv_agg's l1: 1.39061 + 0.113061
# [1900]	cv_agg's l1: 1.37312 + 0.106465
# [2000]	cv_agg's l1: 1.35619 + 0.101276
# [2100]	cv_agg's l1: 1.3406 + 0.0924665
# [2200]	cv_agg's l1: 1.33087 + 0.0891673
# [2300]	cv_agg's l1: 1.32144 + 0.0865695
# [2400]	cv_agg's l1: 1.31324 + 0.0827614
# [2500]	cv_agg's l1: 1.30671 + 0.0811521
# [2600]	cv_agg's l1: 1.29954 + 0.0816368
# [2700]	cv_agg's l1: 1.29488 + 0.0812675
# [2800]	cv_agg's l1: 1.28961 + 0.0798045
# [2900]	cv_agg's l1: 1.28535 + 0.078089
# [3000]	cv_agg's l1: 1.28316 + 0.0786691
# [3100]	cv_agg's l1: 1.28049 + 0.0797873
# [3200]	cv_agg's l1: 1.27853 + 0.0808831
# [3300]	cv_agg's l1: 1.2764 + 0.0820343
# [3400]	cv_agg's l1: 1.27406 + 0.0820933
# [3500]	cv_agg's l1: 1.27106 + 0.0816465
# [3600]	cv_agg's l1: 1.26861 + 0.0808291
# [3700]	cv_agg's l1: 1.26506 + 0.0797993
# [3800]	cv_agg's l1: 1.26224 + 0.0798947
# [3900]	cv_agg's l1: 1.25885 + 0.0785123
# [4000]	cv_agg's l1: 1.25647 + 0.07828
# [4100]	cv_agg's l1: 1.25364 + 0.0779848
# [4200]	cv_agg's l1: 1.25151 + 0.077813
# [4300]	cv_agg's l1: 1.24761 + 0.0754863
# [4400]	cv_agg's l1: 1.24557 + 0.0748878
# [4500]	cv_agg's l1: 1.24425 + 0.0747817
# [4600]	cv_agg's l1: 1.24243 + 0.0748095
# [4700]	cv_agg's l1: 1.24116 + 0.0749652
# [4800]	cv_agg's l1: 1.23943 + 0.0748064
# [4900]	cv_agg's l1: 1.23847 + 0.0752696
# [5000]	cv_agg's l1: 1.2377 + 0.0759376
# [5100]	cv_agg's l1: 1.23679 + 0.0758801
# [5200]	cv_agg's l1: 1.23636 + 0.0765806
# [5300]	cv_agg's l1: 1.23616 + 0.0771195
# [5400]	cv_agg's l1: 1.23547 + 0.0771586
# [5500]	cv_agg's l1: 1.2349 + 0.0776378
# [5600]	cv_agg's l1: 1.23448 + 0.0778314
# [5700]	cv_agg's l1: 1.23325 + 0.0778231
# [5800]	cv_agg's l1: 1.23238 + 0.077796
# [5900]	cv_agg's l1: 1.23135 + 0.0779276
# [6000]	cv_agg's l1: 1.23087 + 0.0778909
# [6100]	cv_agg's l1: 1.22975 + 0.0777302
# [6200]	cv_agg's l1: 1.22852 + 0.0774147
# [6300]	cv_agg's l1: 1.22736 + 0.0770011
# [6400]	cv_agg's l1: 1.22684 + 0.0771463
# [6500]	cv_agg's l1: 1.22597 + 0.0768866
# [6600]	cv_agg's l1: 1.2253 + 0.0768877
# [6700]	cv_agg's l1: 1.22448 + 0.0765445
# [6800]	cv_agg's l1: 1.22386 + 0.0763066
# Run done, took: 2.55 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.00908 + 0.200121
# [200]	cv_agg's l1: 4.2657 + 0.231404
# [300]	cv_agg's l1: 3.64843 + 0.256629
# [400]	cv_agg's l1: 3.14619 + 0.281847
# [500]	cv_agg's l1: 2.74615 + 0.282605
# [600]	cv_agg's l1: 2.42838 + 0.254195
# [700]	cv_agg's l1: 2.19816 + 0.226257
# [800]	cv_agg's l1: 2.01931 + 0.192607
# [900]	cv_agg's l1: 1.87089 + 0.172842
# [1000]	cv_agg's l1: 1.75392 + 0.158294
# [1100]	cv_agg's l1: 1.65808 + 0.141859
# [1200]	cv_agg's l1: 1.58583 + 0.119689
# [1300]	cv_agg's l1: 1.53019 + 0.100342
# [1400]	cv_agg's l1: 1.48414 + 0.0892432
# [1500]	cv_agg's l1: 1.45114 + 0.0806526
# [1600]	cv_agg's l1: 1.42132 + 0.0798414
# [1700]	cv_agg's l1: 1.39397 + 0.0833701
# [1800]	cv_agg's l1: 1.37238 + 0.0829708
# [1900]	cv_agg's l1: 1.35763 + 0.0841552
# [2000]	cv_agg's l1: 1.34713 + 0.0827632
# [2100]	cv_agg's l1: 1.33825 + 0.0836622
# [2200]	cv_agg's l1: 1.32801 + 0.0813738
# [2300]	cv_agg's l1: 1.31964 + 0.0811693
# [2400]	cv_agg's l1: 1.3142 + 0.0821972
# [2500]	cv_agg's l1: 1.30915 + 0.0826061
# [2600]	cv_agg's l1: 1.30575 + 0.0809985
# [2700]	cv_agg's l1: 1.30189 + 0.0806629
# [2800]	cv_agg's l1: 1.29718 + 0.0805152
# [2900]	cv_agg's l1: 1.294 + 0.0808401
# [3000]	cv_agg's l1: 1.28979 + 0.0803988
# [3100]	cv_agg's l1: 1.28582 + 0.0796352
# [3200]	cv_agg's l1: 1.28258 + 0.0797401
# [3300]	cv_agg's l1: 1.28003 + 0.0791485
# [3400]	cv_agg's l1: 1.27593 + 0.0769798
# [3500]	cv_agg's l1: 1.27351 + 0.0755364
# [3600]	cv_agg's l1: 1.26949 + 0.0735611
# [3700]	cv_agg's l1: 1.26626 + 0.0726115
# [3800]	cv_agg's l1: 1.26378 + 0.0724904
# [3900]	cv_agg's l1: 1.26202 + 0.0724281
# [4000]	cv_agg's l1: 1.25924 + 0.0718691
# [4100]	cv_agg's l1: 1.25602 + 0.0706628
# [4200]	cv_agg's l1: 1.2536 + 0.0703963
# [4300]	cv_agg's l1: 1.25189 + 0.0699747
# [4400]	cv_agg's l1: 1.25127 + 0.0699402
# [4500]	cv_agg's l1: 1.2503 + 0.0696242
# [4600]	cv_agg's l1: 1.24936 + 0.0692684
# [4700]	cv_agg's l1: 1.24824 + 0.0688442
# [4800]	cv_agg's l1: 1.24653 + 0.0682138
# [4900]	cv_agg's l1: 1.24521 + 0.0680123
# [5000]	cv_agg's l1: 1.24461 + 0.0680768
# [5100]	cv_agg's l1: 1.24375 + 0.0678582
# [5200]	cv_agg's l1: 1.24305 + 0.0673908
# [5300]	cv_agg's l1: 1.24221 + 0.06694
# [5400]	cv_agg's l1: 1.24115 + 0.0667089
# [5500]	cv_agg's l1: 1.24024 + 0.0666259
# [5600]	cv_agg's l1: 1.2394 + 0.0662288
# [5700]	cv_agg's l1: 1.23869 + 0.0656056
# [5800]	cv_agg's l1: 1.23733 + 0.0647701
# [5900]	cv_agg's l1: 1.23602 + 0.0638691
# [6000]	cv_agg's l1: 1.23464 + 0.0632917
# [6100]	cv_agg's l1: 1.23373 + 0.0628245
# [6200]	cv_agg's l1: 1.23262 + 0.0621301
# [6300]	cv_agg's l1: 1.23161 + 0.0614233
# [6400]	cv_agg's l1: 1.23112 + 0.0610397
# [6500]	cv_agg's l1: 1.23005 + 0.0604694
# [6600]	cv_agg's l1: 1.22946 + 0.0602099
# [6700]	cv_agg's l1: 1.22908 + 0.0598317
# [6800]	cv_agg's l1: 1.22832 + 0.059325
# [6900]	cv_agg's l1: 1.22782 + 0.0589192
# [7000]	cv_agg's l1: 1.22735 + 0.0586679
# [7100]	cv_agg's l1: 1.22629 + 0.0578397
# [7200]	cv_agg's l1: 1.22538 + 0.0573602
# [7300]	cv_agg's l1: 1.22408 + 0.0568156
# [7400]	cv_agg's l1: 1.22265 + 0.0559499
# [7500]	cv_agg's l1: 1.22188 + 0.0555442
# [7600]	cv_agg's l1: 1.22151 + 0.0553886
# Run done, took: 4.05 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.00908 + 0.200121
# [200]	cv_agg's l1: 4.2657 + 0.231404
# [300]	cv_agg's l1: 3.64843 + 0.256629
# [400]	cv_agg's l1: 3.14619 + 0.281847
# [500]	cv_agg's l1: 2.74615 + 0.282605
# [600]	cv_agg's l1: 2.42838 + 0.254195
# [700]	cv_agg's l1: 2.19816 + 0.226257
# [800]	cv_agg's l1: 2.01931 + 0.192607
# [900]	cv_agg's l1: 1.87089 + 0.172842
# [1000]	cv_agg's l1: 1.75392 + 0.158294
# [1100]	cv_agg's l1: 1.65808 + 0.141859
# [1200]	cv_agg's l1: 1.58583 + 0.119689
# [1300]	cv_agg's l1: 1.53019 + 0.100342
# [1400]	cv_agg's l1: 1.48414 + 0.0892432
# [1500]	cv_agg's l1: 1.45114 + 0.0806526
# [1600]	cv_agg's l1: 1.42132 + 0.0798414
# [1700]	cv_agg's l1: 1.39397 + 0.0833701
# [1800]	cv_agg's l1: 1.37238 + 0.0829708
# [1900]	cv_agg's l1: 1.35763 + 0.0841552
# [2000]	cv_agg's l1: 1.34713 + 0.0827632
# [2100]	cv_agg's l1: 1.33825 + 0.0836622
# [2200]	cv_agg's l1: 1.32801 + 0.0813738
# [2300]	cv_agg's l1: 1.31964 + 0.0811693
# [2400]	cv_agg's l1: 1.3142 + 0.0821972
# [2500]	cv_agg's l1: 1.30915 + 0.0826061
# [2600]	cv_agg's l1: 1.30575 + 0.0809985
# [2700]	cv_agg's l1: 1.30189 + 0.0806629
# [2800]	cv_agg's l1: 1.29718 + 0.0805152
# [2900]	cv_agg's l1: 1.294 + 0.0808401
# [3000]	cv_agg's l1: 1.28979 + 0.0803988
# [3100]	cv_agg's l1: 1.28582 + 0.0796352
# [3200]	cv_agg's l1: 1.28258 + 0.0797401
# [3300]	cv_agg's l1: 1.28003 + 0.0791485
# [3400]	cv_agg's l1: 1.27593 + 0.0769798
# [3500]	cv_agg's l1: 1.27351 + 0.0755364
# [3600]	cv_agg's l1: 1.26949 + 0.0735611
# [3700]	cv_agg's l1: 1.26626 + 0.0726115
# [3800]	cv_agg's l1: 1.26378 + 0.0724904
# [3900]	cv_agg's l1: 1.26202 + 0.0724281
# [4000]	cv_agg's l1: 1.25924 + 0.0718691
# [4100]	cv_agg's l1: 1.25602 + 0.0706628
# [4200]	cv_agg's l1: 1.2536 + 0.0703963
# [4300]	cv_agg's l1: 1.25189 + 0.0699747
# [4400]	cv_agg's l1: 1.25127 + 0.0699402
# [4500]	cv_agg's l1: 1.2503 + 0.0696242
# [4600]	cv_agg's l1: 1.24936 + 0.0692684
# [4700]	cv_agg's l1: 1.24824 + 0.0688442
# [4800]	cv_agg's l1: 1.24653 + 0.0682138
# [4900]	cv_agg's l1: 1.24521 + 0.0680123
# [5000]	cv_agg's l1: 1.24461 + 0.0680768
# [5100]	cv_agg's l1: 1.24375 + 0.0678582
# [5200]	cv_agg's l1: 1.24305 + 0.0673908
# [5300]	cv_agg's l1: 1.24221 + 0.06694
# [5400]	cv_agg's l1: 1.24115 + 0.0667089
# [5500]	cv_agg's l1: 1.24024 + 0.0666259
# [5600]	cv_agg's l1: 1.2394 + 0.0662288
# [5700]	cv_agg's l1: 1.23869 + 0.0656056
# [5800]	cv_agg's l1: 1.23733 + 0.0647701
# [5900]	cv_agg's l1: 1.23602 + 0.0638691
# [6000]	cv_agg's l1: 1.23464 + 0.0632917
# [6100]	cv_agg's l1: 1.23373 + 0.0628245
# [6200]	cv_agg's l1: 1.23262 + 0.0621301
# [6300]	cv_agg's l1: 1.23161 + 0.0614233
# [6400]	cv_agg's l1: 1.23112 + 0.0610397
# [6500]	cv_agg's l1: 1.23005 + 0.0604694
# [6600]	cv_agg's l1: 1.22946 + 0.0602099
# [6700]	cv_agg's l1: 1.22908 + 0.0598317
# [6800]	cv_agg's l1: 1.22832 + 0.059325
# [6900]	cv_agg's l1: 1.22782 + 0.0589192
# [7000]	cv_agg's l1: 1.22735 + 0.0586679
# [7100]	cv_agg's l1: 1.22629 + 0.0578397
# [7200]	cv_agg's l1: 1.22538 + 0.0573602
# [7300]	cv_agg's l1: 1.22408 + 0.0568156
# [7400]	cv_agg's l1: 1.22265 + 0.0559499
# [7500]	cv_agg's l1: 1.22188 + 0.0555442
# [7600]	cv_agg's l1: 1.22151 + 0.0553886
# Run done, took: 4.51 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 5.00908 + 0.200121
# [200]	cv_agg's l1: 4.2657 + 0.231404
# [300]	cv_agg's l1: 3.64843 + 0.256629
# [400]	cv_agg's l1: 3.14619 + 0.281847
# [500]	cv_agg's l1: 2.74615 + 0.282605
# [600]	cv_agg's l1: 2.42838 + 0.254195
# [700]	cv_agg's l1: 2.19816 + 0.226257
# [800]	cv_agg's l1: 2.01931 + 0.192607
# [900]	cv_agg's l1: 1.87089 + 0.172842
# [1000]	cv_agg's l1: 1.75392 + 0.158294
# [1100]	cv_agg's l1: 1.65808 + 0.141859
# [1200]	cv_agg's l1: 1.58583 + 0.119689
# [1300]	cv_agg's l1: 1.53019 + 0.100342
# [1400]	cv_agg's l1: 1.48414 + 0.0892432
# [1500]	cv_agg's l1: 1.45114 + 0.0806526
# [1600]	cv_agg's l1: 1.42132 + 0.0798414
# [1700]	cv_agg's l1: 1.39397 + 0.0833701
# [1800]	cv_agg's l1: 1.37238 + 0.0829708
# [1900]	cv_agg's l1: 1.35763 + 0.0841552
# [2000]	cv_agg's l1: 1.34713 + 0.0827632
# [2100]	cv_agg's l1: 1.33825 + 0.0836622
# [2200]	cv_agg's l1: 1.32801 + 0.0813738
# [2300]	cv_agg's l1: 1.31964 + 0.0811693
# [2400]	cv_agg's l1: 1.3142 + 0.0821972
# [2500]	cv_agg's l1: 1.30915 + 0.0826061
# [2600]	cv_agg's l1: 1.30575 + 0.0809985
# [2700]	cv_agg's l1: 1.30189 + 0.0806629
# [2800]	cv_agg's l1: 1.29718 + 0.0805152
# [2900]	cv_agg's l1: 1.294 + 0.0808401
# [3000]	cv_agg's l1: 1.28979 + 0.0803988
# [3100]	cv_agg's l1: 1.28582 + 0.0796352
# [3200]	cv_agg's l1: 1.28258 + 0.0797401
# [3300]	cv_agg's l1: 1.28003 + 0.0791485
# [3400]	cv_agg's l1: 1.27593 + 0.0769798
# [3500]	cv_agg's l1: 1.27351 + 0.0755364
# [3600]	cv_agg's l1: 1.26949 + 0.0735611
# [3700]	cv_agg's l1: 1.26626 + 0.0726115
# [3800]	cv_agg's l1: 1.26378 + 0.0724904
# [3900]	cv_agg's l1: 1.26202 + 0.0724281
# [4000]	cv_agg's l1: 1.25924 + 0.0718691
# [4100]	cv_agg's l1: 1.25602 + 0.0706628
# [4200]	cv_agg's l1: 1.2536 + 0.0703963
# [4300]	cv_agg's l1: 1.25189 + 0.0699747
# [4400]	cv_agg's l1: 1.25127 + 0.0699402
# [4500]	cv_agg's l1: 1.2503 + 0.0696242
# [4600]	cv_agg's l1: 1.24936 + 0.0692684
# [4700]	cv_agg's l1: 1.24824 + 0.0688442
# [4800]	cv_agg's l1: 1.24653 + 0.0682138
# [4900]	cv_agg's l1: 1.24521 + 0.0680123
# [5000]	cv_agg's l1: 1.24461 + 0.0680768
# [5100]	cv_agg's l1: 1.24375 + 0.0678582
# [5200]	cv_agg's l1: 1.24305 + 0.0673908
# [5300]	cv_agg's l1: 1.24221 + 0.06694
# [5400]	cv_agg's l1: 1.24115 + 0.0667089
# [5500]	cv_agg's l1: 1.24024 + 0.0666259
# [5600]	cv_agg's l1: 1.2394 + 0.0662288
# [5700]	cv_agg's l1: 1.23869 + 0.0656056
# [5800]	cv_agg's l1: 1.23733 + 0.0647701
# [5900]	cv_agg's l1: 1.23602 + 0.0638691
# [6000]	cv_agg's l1: 1.23464 + 0.0632917
# [6100]	cv_agg's l1: 1.23373 + 0.0628245
# [6200]	cv_agg's l1: 1.23262 + 0.0621301
# [6300]	cv_agg's l1: 1.23161 + 0.0614233
# [6400]	cv_agg's l1: 1.23112 + 0.0610397
# [6500]	cv_agg's l1: 1.23005 + 0.0604694
# [6600]	cv_agg's l1: 1.22946 + 0.0602099
# [6700]	cv_agg's l1: 1.22908 + 0.0598317
# [6800]	cv_agg's l1: 1.22832 + 0.059325
# [6900]	cv_agg's l1: 1.22782 + 0.0589192
# [7000]	cv_agg's l1: 1.22735 + 0.0586679
# [7100]	cv_agg's l1: 1.22629 + 0.0578397
# [7200]	cv_agg's l1: 1.22538 + 0.0573602
# [7300]	cv_agg's l1: 1.22408 + 0.0568156
# [7400]	cv_agg's l1: 1.22265 + 0.0559499
# [7500]	cv_agg's l1: 1.22188 + 0.0555442
# [7600]	cv_agg's l1: 1.22151 + 0.0553886
# Run done, took: 5.92 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 7626}, 1.221455244865355)
# Wall time: 19.2 s

# %%
# %%time
code4_model_outer = optimisedLGM(param_grid,mixed_outer_train,code4data_mixed["outCityFare"])
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.9694 + 0.185738
# [200]	cv_agg's l1: 11.7433 + 0.196496
# [300]	cv_agg's l1: 9.9778 + 0.248449
# [400]	cv_agg's l1: 8.68618 + 0.326935
# [500]	cv_agg's l1: 7.68028 + 0.391488
# [600]	cv_agg's l1: 6.92449 + 0.462614
# [700]	cv_agg's l1: 6.34281 + 0.491375
# [800]	cv_agg's l1: 5.89049 + 0.472631
# [900]	cv_agg's l1: 5.56923 + 0.446653
# [1000]	cv_agg's l1: 5.34447 + 0.444082
# [1100]	cv_agg's l1: 5.1905 + 0.446727
# [1200]	cv_agg's l1: 5.08421 + 0.453382
# [1300]	cv_agg's l1: 5.01355 + 0.458184
# [1400]	cv_agg's l1: 4.95422 + 0.448029
# [1500]	cv_agg's l1: 4.90562 + 0.439323
# [1600]	cv_agg's l1: 4.86751 + 0.435455
# [1700]	cv_agg's l1: 4.84104 + 0.4276
# [1800]	cv_agg's l1: 4.81515 + 0.417805
# [1900]	cv_agg's l1: 4.79853 + 0.413504
# [2000]	cv_agg's l1: 4.79133 + 0.409876
# [2100]	cv_agg's l1: 4.7858 + 0.404387
# [2200]	cv_agg's l1: 4.7826 + 0.401933
# [2300]	cv_agg's l1: 4.77954 + 0.400758
# [2400]	cv_agg's l1: 4.77716 + 0.399525
# [2500]	cv_agg's l1: 4.77391 + 0.397941
# [2600]	cv_agg's l1: 4.77059 + 0.39861
# [2700]	cv_agg's l1: 4.76858 + 0.399231
# [2800]	cv_agg's l1: 4.76502 + 0.39908
# [2900]	cv_agg's l1: 4.76339 + 0.397858
# [3000]	cv_agg's l1: 4.76228 + 0.394735
# [3100]	cv_agg's l1: 4.76145 + 0.392049
# Run done, took: 1.35 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.8189 + 0.112058
# [200]	cv_agg's l1: 11.3923 + 0.147409
# [300]	cv_agg's l1: 9.56937 + 0.22759
# [400]	cv_agg's l1: 8.22294 + 0.322745
# [500]	cv_agg's l1: 7.21301 + 0.426997
# [600]	cv_agg's l1: 6.49826 + 0.476171
# [700]	cv_agg's l1: 5.99643 + 0.470977
# [800]	cv_agg's l1: 5.65308 + 0.461261
# [900]	cv_agg's l1: 5.40567 + 0.446431
# [1000]	cv_agg's l1: 5.22766 + 0.429363
# [1100]	cv_agg's l1: 5.10889 + 0.412976
# [1200]	cv_agg's l1: 5.01818 + 0.395165
# [1300]	cv_agg's l1: 4.9552 + 0.387029
# [1400]	cv_agg's l1: 4.90842 + 0.376849
# [1500]	cv_agg's l1: 4.87806 + 0.364958
# [1600]	cv_agg's l1: 4.85214 + 0.357429
# [1700]	cv_agg's l1: 4.83636 + 0.356843
# [1800]	cv_agg's l1: 4.82552 + 0.354316
# [1900]	cv_agg's l1: 4.81751 + 0.353226
# [2000]	cv_agg's l1: 4.81136 + 0.349627
# [2100]	cv_agg's l1: 4.80642 + 0.346525
# [2200]	cv_agg's l1: 4.80464 + 0.343414
# [2300]	cv_agg's l1: 4.80127 + 0.339583
# [2400]	cv_agg's l1: 4.79787 + 0.335971
# [2500]	cv_agg's l1: 4.79417 + 0.334275
# [2600]	cv_agg's l1: 4.79057 + 0.332312
# [2700]	cv_agg's l1: 4.78892 + 0.329634
# [2800]	cv_agg's l1: 4.78871 + 0.325957
# Run done, took: 1.69 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.8189 + 0.112058
# [200]	cv_agg's l1: 11.3923 + 0.147409
# [300]	cv_agg's l1: 9.56937 + 0.22759
# [400]	cv_agg's l1: 8.22294 + 0.322745
# [500]	cv_agg's l1: 7.21301 + 0.426997
# [600]	cv_agg's l1: 6.49826 + 0.476171
# [700]	cv_agg's l1: 5.99643 + 0.470977
# [800]	cv_agg's l1: 5.65308 + 0.461261
# [900]	cv_agg's l1: 5.40567 + 0.446431
# [1000]	cv_agg's l1: 5.22766 + 0.429363
# [1100]	cv_agg's l1: 5.10889 + 0.412976
# [1200]	cv_agg's l1: 5.01818 + 0.395165
# [1300]	cv_agg's l1: 4.9552 + 0.387029
# [1400]	cv_agg's l1: 4.90842 + 0.376849
# [1500]	cv_agg's l1: 4.87806 + 0.364958
# [1600]	cv_agg's l1: 4.85214 + 0.357429
# [1700]	cv_agg's l1: 4.83636 + 0.356843
# [1800]	cv_agg's l1: 4.82552 + 0.354316
# [1900]	cv_agg's l1: 4.81751 + 0.353226
# [2000]	cv_agg's l1: 4.81136 + 0.349627
# [2100]	cv_agg's l1: 4.80642 + 0.346525
# [2200]	cv_agg's l1: 4.80464 + 0.343414
# [2300]	cv_agg's l1: 4.80127 + 0.339583
# [2400]	cv_agg's l1: 4.79787 + 0.335971
# [2500]	cv_agg's l1: 4.79417 + 0.334275
# [2600]	cv_agg's l1: 4.79057 + 0.332312
# [2700]	cv_agg's l1: 4.78892 + 0.329634
# [2800]	cv_agg's l1: 4.78871 + 0.325957
# Run done, took: 1.66 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.8189 + 0.112058
# [200]	cv_agg's l1: 11.3923 + 0.147409
# [300]	cv_agg's l1: 9.56937 + 0.22759
# [400]	cv_agg's l1: 8.22294 + 0.322745
# [500]	cv_agg's l1: 7.21301 + 0.426997
# [600]	cv_agg's l1: 6.49826 + 0.476171
# [700]	cv_agg's l1: 5.99643 + 0.470977
# [800]	cv_agg's l1: 5.65308 + 0.461261
# [900]	cv_agg's l1: 5.40567 + 0.446431
# [1000]	cv_agg's l1: 5.22766 + 0.429363
# [1100]	cv_agg's l1: 5.10889 + 0.412976
# [1200]	cv_agg's l1: 5.01818 + 0.395165
# [1300]	cv_agg's l1: 4.9552 + 0.387029
# [1400]	cv_agg's l1: 4.90842 + 0.376849
# [1500]	cv_agg's l1: 4.87806 + 0.364958
# [1600]	cv_agg's l1: 4.85214 + 0.357429
# [1700]	cv_agg's l1: 4.83636 + 0.356843
# [1800]	cv_agg's l1: 4.82552 + 0.354316
# [1900]	cv_agg's l1: 4.81751 + 0.353226
# [2000]	cv_agg's l1: 4.81136 + 0.349627
# [2100]	cv_agg's l1: 4.80642 + 0.346525
# [2200]	cv_agg's l1: 4.80464 + 0.343414
# [2300]	cv_agg's l1: 4.80127 + 0.339583
# [2400]	cv_agg's l1: 4.79787 + 0.335971
# [2500]	cv_agg's l1: 4.79417 + 0.334275
# [2600]	cv_agg's l1: 4.79057 + 0.332312
# [2700]	cv_agg's l1: 4.78892 + 0.329634
# [2800]	cv_agg's l1: 4.78871 + 0.325957
# Run done, took: 2.0 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 3089}, 4.76103655631419)
# Wall time: 7.07 s

# %%
# %%time
features_combined = ["inCityTripDistance","outCityTripDistance","duration","trip_distance","ridesAtPickupHour","avg_speed"]
code4_model_combined = optimisedLGM(param_grid,code4data_mixed[features_combined],code4data_mixed["fare_amount"]-2.5)
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.2909 + 0.47195
# [200]	cv_agg's l1: 11.3807 + 0.562286
# [300]	cv_agg's l1: 9.89418 + 0.657115
# [400]	cv_agg's l1: 8.79725 + 0.639258
# [500]	cv_agg's l1: 7.92503 + 0.664989
# [600]	cv_agg's l1: 7.23802 + 0.675585
# [700]	cv_agg's l1: 6.79911 + 0.631336
# [800]	cv_agg's l1: 6.50578 + 0.581659
# [900]	cv_agg's l1: 6.27979 + 0.543574
# [1000]	cv_agg's l1: 6.13703 + 0.531509
# [1100]	cv_agg's l1: 6.01149 + 0.52059
# [1200]	cv_agg's l1: 5.92716 + 0.527312
# [1300]	cv_agg's l1: 5.87632 + 0.526887
# [1400]	cv_agg's l1: 5.83819 + 0.518412
# [1500]	cv_agg's l1: 5.813 + 0.513748
# [1600]	cv_agg's l1: 5.78868 + 0.513251
# [1700]	cv_agg's l1: 5.76992 + 0.51043
# [1800]	cv_agg's l1: 5.74903 + 0.504425
# [1900]	cv_agg's l1: 5.73401 + 0.497419
# [2000]	cv_agg's l1: 5.72385 + 0.493412
# [2100]	cv_agg's l1: 5.71504 + 0.490971
# [2200]	cv_agg's l1: 5.71089 + 0.486562
# [2300]	cv_agg's l1: 5.7084 + 0.484427
# [2400]	cv_agg's l1: 5.70415 + 0.482032
# [2500]	cv_agg's l1: 5.70087 + 0.480627
# [2600]	cv_agg's l1: 5.69588 + 0.477938
# [2700]	cv_agg's l1: 5.69116 + 0.474679
# [2800]	cv_agg's l1: 5.68773 + 0.472449
# [2900]	cv_agg's l1: 5.68555 + 0.471398
# [3000]	cv_agg's l1: 5.68355 + 0.469856
# Run done, took: 1.17 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.0731 + 0.423947
# [200]	cv_agg's l1: 10.9914 + 0.481132
# [300]	cv_agg's l1: 9.40796 + 0.538815
# [400]	cv_agg's l1: 8.27113 + 0.597529
# [500]	cv_agg's l1: 7.4144 + 0.626949
# [600]	cv_agg's l1: 6.82543 + 0.620805
# [700]	cv_agg's l1: 6.45682 + 0.561084
# [800]	cv_agg's l1: 6.21843 + 0.513202
# [900]	cv_agg's l1: 6.05902 + 0.48491
# [1000]	cv_agg's l1: 5.94685 + 0.464182
# [1100]	cv_agg's l1: 5.87399 + 0.454416
# [1200]	cv_agg's l1: 5.82286 + 0.450984
# [1300]	cv_agg's l1: 5.78581 + 0.444231
# [1400]	cv_agg's l1: 5.74845 + 0.43573
# [1500]	cv_agg's l1: 5.72101 + 0.42773
# [1600]	cv_agg's l1: 5.69598 + 0.41984
# [1700]	cv_agg's l1: 5.67807 + 0.414836
# [1800]	cv_agg's l1: 5.66337 + 0.412786
# [1900]	cv_agg's l1: 5.65338 + 0.410068
# [2000]	cv_agg's l1: 5.6459 + 0.41051
# [2100]	cv_agg's l1: 5.63909 + 0.409433
# [2200]	cv_agg's l1: 5.6325 + 0.405968
# [2300]	cv_agg's l1: 5.62787 + 0.403776
# [2400]	cv_agg's l1: 5.624 + 0.40398
# [2500]	cv_agg's l1: 5.61835 + 0.403276
# [2600]	cv_agg's l1: 5.61675 + 0.402684
# [2700]	cv_agg's l1: 5.61489 + 0.401387
# [2800]	cv_agg's l1: 5.61372 + 0.40187
# [2900]	cv_agg's l1: 5.60918 + 0.401083
# [3000]	cv_agg's l1: 5.60523 + 0.401094
# [3100]	cv_agg's l1: 5.60226 + 0.400595
# [3200]	cv_agg's l1: 5.59969 + 0.40061
# [3300]	cv_agg's l1: 5.59824 + 0.399936
# [3400]	cv_agg's l1: 5.59622 + 0.399622
# [3500]	cv_agg's l1: 5.59349 + 0.401175
# [3600]	cv_agg's l1: 5.59221 + 0.40183
# [3700]	cv_agg's l1: 5.59065 + 0.403927
# [3800]	cv_agg's l1: 5.58963 + 0.404864
# Run done, took: 2.08 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.0731 + 0.423947
# [200]	cv_agg's l1: 10.9914 + 0.481132
# [300]	cv_agg's l1: 9.40796 + 0.538815
# [400]	cv_agg's l1: 8.27113 + 0.597529
# [500]	cv_agg's l1: 7.4144 + 0.626949
# [600]	cv_agg's l1: 6.82543 + 0.620805
# [700]	cv_agg's l1: 6.45682 + 0.561084
# [800]	cv_agg's l1: 6.21843 + 0.513202
# [900]	cv_agg's l1: 6.05902 + 0.48491
# [1000]	cv_agg's l1: 5.94685 + 0.464182
# [1100]	cv_agg's l1: 5.87399 + 0.454416
# [1200]	cv_agg's l1: 5.82286 + 0.450984
# [1300]	cv_agg's l1: 5.78581 + 0.444231
# [1400]	cv_agg's l1: 5.74845 + 0.43573
# [1500]	cv_agg's l1: 5.72101 + 0.42773
# [1600]	cv_agg's l1: 5.69598 + 0.41984
# [1700]	cv_agg's l1: 5.67807 + 0.414836
# [1800]	cv_agg's l1: 5.66337 + 0.412786
# [1900]	cv_agg's l1: 5.65338 + 0.410068
# [2000]	cv_agg's l1: 5.6459 + 0.41051
# [2100]	cv_agg's l1: 5.63909 + 0.409433
# [2200]	cv_agg's l1: 5.6325 + 0.405968
# [2300]	cv_agg's l1: 5.62787 + 0.403776
# [2400]	cv_agg's l1: 5.624 + 0.40398
# [2500]	cv_agg's l1: 5.61835 + 0.403276
# [2600]	cv_agg's l1: 5.61675 + 0.402684
# [2700]	cv_agg's l1: 5.61489 + 0.401387
# [2800]	cv_agg's l1: 5.61372 + 0.40187
# [2900]	cv_agg's l1: 5.60918 + 0.401083
# [3000]	cv_agg's l1: 5.60523 + 0.401094
# [3100]	cv_agg's l1: 5.60226 + 0.400595
# [3200]	cv_agg's l1: 5.59969 + 0.40061
# [3300]	cv_agg's l1: 5.59824 + 0.399936
# [3400]	cv_agg's l1: 5.59622 + 0.399622
# [3500]	cv_agg's l1: 5.59349 + 0.401175
# [3600]	cv_agg's l1: 5.59221 + 0.40183
# [3700]	cv_agg's l1: 5.59065 + 0.403927
# [3800]	cv_agg's l1: 5.58963 + 0.404864
# Run done, took: 2.28 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 13.0731 + 0.423947
# [200]	cv_agg's l1: 10.9914 + 0.481132
# [300]	cv_agg's l1: 9.40796 + 0.538815
# [400]	cv_agg's l1: 8.27113 + 0.597529
# [500]	cv_agg's l1: 7.4144 + 0.626949
# [600]	cv_agg's l1: 6.82543 + 0.620805
# [700]	cv_agg's l1: 6.45682 + 0.561084
# [800]	cv_agg's l1: 6.21843 + 0.513202
# [900]	cv_agg's l1: 6.05902 + 0.48491
# [1000]	cv_agg's l1: 5.94685 + 0.464182
# [1100]	cv_agg's l1: 5.87399 + 0.454416
# [1200]	cv_agg's l1: 5.82286 + 0.450984
# [1300]	cv_agg's l1: 5.78581 + 0.444231
# [1400]	cv_agg's l1: 5.74845 + 0.43573
# [1500]	cv_agg's l1: 5.72101 + 0.42773
# [1600]	cv_agg's l1: 5.69598 + 0.41984
# [1700]	cv_agg's l1: 5.67807 + 0.414836
# [1800]	cv_agg's l1: 5.66337 + 0.412786
# [1900]	cv_agg's l1: 5.65338 + 0.410068
# [2000]	cv_agg's l1: 5.6459 + 0.41051
# [2100]	cv_agg's l1: 5.63909 + 0.409433
# [2200]	cv_agg's l1: 5.6325 + 0.405968
# [2300]	cv_agg's l1: 5.62787 + 0.403776
# [2400]	cv_agg's l1: 5.624 + 0.40398
# [2500]	cv_agg's l1: 5.61835 + 0.403276
# [2600]	cv_agg's l1: 5.61675 + 0.402684
# [2700]	cv_agg's l1: 5.61489 + 0.401387
# [2800]	cv_agg's l1: 5.61372 + 0.40187
# [2900]	cv_agg's l1: 5.60918 + 0.401083
# [3000]	cv_agg's l1: 5.60523 + 0.401094
# [3100]	cv_agg's l1: 5.60226 + 0.400595
# [3200]	cv_agg's l1: 5.59969 + 0.40061
# [3300]	cv_agg's l1: 5.59824 + 0.399936
# [3400]	cv_agg's l1: 5.59622 + 0.399622
# [3500]	cv_agg's l1: 5.59349 + 0.401175
# [3600]	cv_agg's l1: 5.59221 + 0.40183
# [3700]	cv_agg's l1: 5.59065 + 0.403927
# [3800]	cv_agg's l1: 5.58963 + 0.404864
# Run done, took: 2.61 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 3818}, 5.589351636352185)
# Wall time: 9.11 s

# %% [markdown]
# Next: model for outer trips.

# %%
# %%time
# make train set
features = ["passenger_count","trip_distance","payment_type","duration","ridesAtPickupHour","avg_speed"]

code4_model_out = optimisedLGM(param_grid,code4data_out[features],code4data_out["fare_amount"]-2.5)
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 14.8289 + 0.426395
# [200]	cv_agg's l1: 12.0215 + 0.407695
# [300]	cv_agg's l1: 10.0819 + 0.366496
# [400]	cv_agg's l1: 8.71231 + 0.318549
# [500]	cv_agg's l1: 7.75431 + 0.279955
# [600]	cv_agg's l1: 7.10942 + 0.265774
# [700]	cv_agg's l1: 6.65849 + 0.26131
# [800]	cv_agg's l1: 6.34508 + 0.260357
# [900]	cv_agg's l1: 6.11832 + 0.258681
# [1000]	cv_agg's l1: 5.96211 + 0.258101
# [1100]	cv_agg's l1: 5.85098 + 0.264435
# [1200]	cv_agg's l1: 5.7661 + 0.262173
# [1300]	cv_agg's l1: 5.70041 + 0.261962
# [1400]	cv_agg's l1: 5.65028 + 0.258309
# [1500]	cv_agg's l1: 5.6122 + 0.255927
# [1600]	cv_agg's l1: 5.58595 + 0.249896
# [1700]	cv_agg's l1: 5.56719 + 0.247696
# [1800]	cv_agg's l1: 5.55389 + 0.248278
# [1900]	cv_agg's l1: 5.54173 + 0.250634
# [2000]	cv_agg's l1: 5.53381 + 0.250911
# [2100]	cv_agg's l1: 5.53021 + 0.249142
# [2200]	cv_agg's l1: 5.52802 + 0.248863
# [2300]	cv_agg's l1: 5.52637 + 0.247353
# [2400]	cv_agg's l1: 5.52536 + 0.245694
# [2500]	cv_agg's l1: 5.5227 + 0.24613
# [2600]	cv_agg's l1: 5.52061 + 0.245501
# [2700]	cv_agg's l1: 5.52036 + 0.244097
# Run done, took: 1.39 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 14.6435 + 0.410133
# [200]	cv_agg's l1: 11.7234 + 0.387871
# [300]	cv_agg's l1: 9.70376 + 0.367965
# [400]	cv_agg's l1: 8.35007 + 0.327046
# [500]	cv_agg's l1: 7.44375 + 0.296551
# [600]	cv_agg's l1: 6.83343 + 0.281136
# [700]	cv_agg's l1: 6.42108 + 0.276884
# [800]	cv_agg's l1: 6.14553 + 0.276713
# [900]	cv_agg's l1: 5.94211 + 0.274675
# [1000]	cv_agg's l1: 5.80319 + 0.27746
# [1100]	cv_agg's l1: 5.70838 + 0.277207
# [1200]	cv_agg's l1: 5.63977 + 0.274386
# [1300]	cv_agg's l1: 5.59183 + 0.271154
# [1400]	cv_agg's l1: 5.56025 + 0.267022
# [1500]	cv_agg's l1: 5.53771 + 0.264889
# [1600]	cv_agg's l1: 5.52079 + 0.263269
# [1700]	cv_agg's l1: 5.50745 + 0.263039
# [1800]	cv_agg's l1: 5.50011 + 0.262217
# [1900]	cv_agg's l1: 5.49618 + 0.261034
# [2000]	cv_agg's l1: 5.49636 + 0.257788
# Run done, took: 2.71 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 14.6315 + 0.405425
# [200]	cv_agg's l1: 11.6889 + 0.390683
# [300]	cv_agg's l1: 9.66617 + 0.372558
# [400]	cv_agg's l1: 8.32042 + 0.336842
# [500]	cv_agg's l1: 7.42222 + 0.299525
# [600]	cv_agg's l1: 6.81707 + 0.276505
# [700]	cv_agg's l1: 6.40266 + 0.271077
# [800]	cv_agg's l1: 6.12337 + 0.264799
# [900]	cv_agg's l1: 5.91908 + 0.262587
# [1000]	cv_agg's l1: 5.78427 + 0.258493
# [1100]	cv_agg's l1: 5.70051 + 0.257465
# [1200]	cv_agg's l1: 5.64155 + 0.255274
# [1300]	cv_agg's l1: 5.60941 + 0.254045
# [1400]	cv_agg's l1: 5.58672 + 0.252592
# [1500]	cv_agg's l1: 5.57198 + 0.252816
# [1600]	cv_agg's l1: 5.56371 + 0.251136
# [1700]	cv_agg's l1: 5.55845 + 0.251644
# [1800]	cv_agg's l1: 5.55611 + 0.250589
# Run done, took: 4.01 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 14.6315 + 0.405425
# [200]	cv_agg's l1: 11.6889 + 0.390683
# [300]	cv_agg's l1: 9.66617 + 0.372558
# [400]	cv_agg's l1: 8.32042 + 0.336842
# [500]	cv_agg's l1: 7.42222 + 0.299525
# [600]	cv_agg's l1: 6.81707 + 0.276505
# [700]	cv_agg's l1: 6.40266 + 0.271077
# [800]	cv_agg's l1: 6.12337 + 0.264799
# [900]	cv_agg's l1: 5.91908 + 0.262587
# [1000]	cv_agg's l1: 5.78427 + 0.258493
# [1100]	cv_agg's l1: 5.70051 + 0.257465
# [1200]	cv_agg's l1: 5.64155 + 0.255274
# [1300]	cv_agg's l1: 5.60941 + 0.254045
# [1400]	cv_agg's l1: 5.58672 + 0.252592
# [1500]	cv_agg's l1: 5.57198 + 0.252816
# [1600]	cv_agg's l1: 5.56371 + 0.251136
# [1700]	cv_agg's l1: 5.55845 + 0.251644
# [1800]	cv_agg's l1: 5.55611 + 0.250589
# Run done, took: 4.39 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 1955}, 5.4957849105668375)
# Wall time: 13.4 s

# %% [markdown]
# ## Prediction

# %%
#apply to test set
code4test["endsInManhattan"] = code4test.apply(lambda x : inArea(manhattan_cords,x["dropoff_latitude"],x["dropoff_longitude"]),axis=1)
code4test["startsInManhattan"] = code4test.apply(lambda x : inArea(manhattan_cords,x["pickup_latitude"],x["pickup_longitude"]),axis=1)

# %% [markdown]
# We have four possible trip patterns:
#     1. starts in city, ends in city --> should not have ratecode 4 -> outlier, ignore
#     2. starts in city, ends out of city -> standard trip
#     3. starts out of city, ends out of city -> no calculations to be done here, use double rate for whole trip
#     4. starts out of city, ends in city -> reverse standard trip

# %%
np.shape(code4test)
# Out:
# (1000, 22)

# %%
#option1: trips that start and end in manhattan, these should not have this ratecode
code4test_wrong = code4test[(code4test.startsInManhattan & code4test.endsInManhattan)]
np.shape(code4test_wrong)
# Out:
# (35, 22)

# %%
#option2 & option 4: 
code4test_mixed = code4test[code4test.startsInManhattan ^ code4test.endsInManhattan] 
np.shape(code4test_mixed)
# Out:
# (238, 22)

# %%
#option 3:
code4test_out = code4test[(code4test.startsInManhattan==False) & (code4test.endsInManhattan==False)] 
np.shape(code4test_out)
# Out:
# (727, 22)

# %%
# try to find out which bridge is used in a trip 
# assumption: the bridge is used that minimizes the pickup-bridge-dropoff distance (air-line distance)
counter = 1
for index, row in code4test_mixed.iterrows():
    
    startP = (row["pickup_latitude"],row["pickup_longitude"])
    endP = (row["dropoff_latitude"],row["dropoff_longitude"])
    
    if(row.startsInManhattan and row.endsInManhattan):
        #print("Outlier found, index",index)
        continue
    elif (not row.startsInManhattan and not row.endsInManhattan):
        #print("Complete out of city trip, index",index)
        code4test_mixed.at[index,"bridge"] = None;
        code4test_mixed.at[index,"in_city_distance"] = 0;
        code4test_mixed.at[index,"out_of_city_distance"] = geodesic(startP, endP).miles
        code4test_mixed.at[index,"total_over_bridge_distance"] = geodesic(startP, endP).miles  
        continue
    elif (not row.startsInManhattan and  row.endsInManhattan): # reverse trip
        temp = startP # here we swap start and endpoints so its similar to a standard trip
        startP = endP
        endP = temp
    
    #find closest bridge
    closest_bridge_index = -1
    closest_total_bridge_distance = float('inf')
    for i in range(len(bridges)):
        distance_to_bridge = geodesic(startP, bridges[i]).miles
        distance_to_dest =  geodesic(bridges[i],endP).miles
        total = distance_to_bridge + distance_to_dest
        if(total < closest_total_bridge_distance):
            closest_total_bridge_distance = total
            closest_bridge_index = i
            closest_distance_to_bridge = distance_to_bridge
            closest_distance_to_dest = distance_to_dest
            
    #print("Route {} travels over bridge/tunnel {} (to bridge: {:0.2f}, to dest: {:0.2f}, total: {:0.2f}, trip_distance : {:0.2f})".format(
    #    counter, closest_bridge_index,closest_distance_to_bridge,closest_distance_to_dest,closest_total_bridge_distance,totalDistance))
    counter = counter + 1
    
    code4test_mixed.at[index,"bridge"] = closest_bridge_index;
    code4test_mixed.at[index,"in_city_distance"] = closest_distance_to_bridge;
    code4test_mixed.at[index,"out_of_city_distance"] = closest_distance_to_dest
    code4test_mixed.at[index,"total_over_bridge_distance"] = closest_total_bridge_distance

# %%
#states how much of the fare was contributed by ride in the city. Calculated by 
code4test_mixed["inCityPercentage"] = code4test_mixed.apply(lambda x: x.in_city_distance/(x.in_city_distance+2*x.out_of_city_distance+0.0001),axis=1)

# %%
code4test_mixed["inCityTripDistance"] = code4test_mixed.apply(lambda x: x.in_city_distance/(x.in_city_distance+x.out_of_city_distance),axis=1)
code4test_mixed["outCityTripDistance"] = code4test_mixed.apply(lambda x: x.out_of_city_distance/(x.in_city_distance+x.out_of_city_distance),axis=1)

# %%
code4test_mixed["inCityTripDistanceExtreme"] = code4test_mixed.apply(lambda x: x.inCityPercentage*x.trip_distance,axis=1)
code4test_mixed["outCityTripDistanceExtreme"] = code4test_mixed.apply(lambda x: (1-x.inCityPercentage)*x.trip_distance,axis=1)

# %%
# prediction for the inner city part
code4_mixed_inner_pred = code4_model_inner.predict(code4test_mixed[features_inner])

# %%
#prediction for out of city part
code4_mixed_outer_pred = code4_model_outer.predict(code4test_mixed[features_outer])

# %%
code4_mixed_combined_pred = code4_model_combined.predict(code4test_mixed[features_combined])

# %%
#combine the results
#round comined predictions to closest .5
#add 2.5 inital charge which was removed before training
code4test_mixed["fare_amount_prediction"]=np.round((code4_mixed_inner_pred+code4_mixed_outer_pred)*2)/2+2.5

# %%
code4test_mixed["fare_amount_prediction"].describe()
# Out:
# count    238.000000
# mean      70.569328
# std       19.635884
# min       16.000000
# 25%       57.500000
# 50%       68.750000
# 75%       92.000000
# max      107.500000
# Name: fare_amount_prediction, dtype: float64

# %%
code4test_mixed["fare_amount_prediction"]=np.round(code4_mixed_combined_pred*2)/2+2.5

# %%
code4test_mixed["fare_amount_prediction"].describe()
# Out:
# count    238.000000
# mean      70.619748
# std       19.482583
# min       16.000000
# 25%       59.125000
# 50%       69.250000
# 75%       91.500000
# max      100.500000
# Name: fare_amount_prediction, dtype: float64

# %% [markdown]
# Next: predict out trips.

# %%
code4test_out_pred = code4_model_out.predict(code4test_out[features])
code4test_out["fare_amount_prediction"]=np.round(code4test_out_pred*2)/2+2.5

# %% [markdown]
# Lastly: predict trips that only were in Manhattan with double rate model (same as outer trips)

# %%
code4_test_wrong_pred = code4_model_out.predict(code4test_wrong[features])
code4test_wrong["fare_amount_prediction"]=np.round(code4_test_wrong_pred*2)/2+2.5

# %%
#combine all code 4 dataframes with predictions
code4test = pd.concat([code4test_mixed,code4test_out,code4test_wrong])

# %% [markdown]
# # Ratecode 5 (Negotiated Fares)

# %% [markdown]
# ## Building the Model

# %%
code5data = train[train.RatecodeID == 5]
code5test = test[test.RatecodeID == 5]

# %%
# %%time
features = ["duration","passenger_count","trip_distance","avg_speed","ridesAtPickupHour"]

code5_model = optimisedLGM(param_grid,code5data[features],code5data["fare_amount"]-2.5)
# Out:
# Total parameter combinations to run: 4
# Starting run 1
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 28.6021 + 0.672588
# [200]	cv_agg's l1: 25.2341 + 0.612016
# [300]	cv_agg's l1: 23.1657 + 0.541671
# [400]	cv_agg's l1: 21.8425 + 0.494742
# [500]	cv_agg's l1: 20.924 + 0.4251
# [600]	cv_agg's l1: 20.3326 + 0.405405
# [700]	cv_agg's l1: 19.9628 + 0.39084
# [800]	cv_agg's l1: 19.715 + 0.384029
# [900]	cv_agg's l1: 19.5337 + 0.364614
# [1000]	cv_agg's l1: 19.4185 + 0.351743
# [1100]	cv_agg's l1: 19.3337 + 0.333693
# [1200]	cv_agg's l1: 19.272 + 0.312675
# [1300]	cv_agg's l1: 19.2387 + 0.297007
# [1400]	cv_agg's l1: 19.2203 + 0.291348
# [1500]	cv_agg's l1: 19.2056 + 0.286667
# [1600]	cv_agg's l1: 19.1979 + 0.284238
# [1700]	cv_agg's l1: 19.1852 + 0.289146
# [1800]	cv_agg's l1: 19.1746 + 0.293921
# [1900]	cv_agg's l1: 19.1675 + 0.300309
# [2000]	cv_agg's l1: 19.1631 + 0.303535
# [2100]	cv_agg's l1: 19.1509 + 0.293674
# [2200]	cv_agg's l1: 19.1432 + 0.288932
# [2300]	cv_agg's l1: 19.1363 + 0.288149
# [2400]	cv_agg's l1: 19.1302 + 0.281785
# [2500]	cv_agg's l1: 19.1257 + 0.287913
# [2600]	cv_agg's l1: 19.1205 + 0.291987
# [2700]	cv_agg's l1: 19.1157 + 0.289534
# [2800]	cv_agg's l1: 19.1133 + 0.288868
# [2900]	cv_agg's l1: 19.1124 + 0.288595
# Run done, took: 2.69 s
# Starting run 2
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 31, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 28.1506 + 0.618805
# [200]	cv_agg's l1: 24.7794 + 0.576372
# [300]	cv_agg's l1: 22.6251 + 0.454557
# [400]	cv_agg's l1: 21.3129 + 0.40272
# [500]	cv_agg's l1: 20.4841 + 0.355126
# [600]	cv_agg's l1: 19.9776 + 0.325461
# [700]	cv_agg's l1: 19.6616 + 0.313272
# [800]	cv_agg's l1: 19.4679 + 0.298099
# [900]	cv_agg's l1: 19.3543 + 0.296169
# [1000]	cv_agg's l1: 19.2888 + 0.294573
# [1100]	cv_agg's l1: 19.2463 + 0.290263
# [1200]	cv_agg's l1: 19.2104 + 0.28222
# [1300]	cv_agg's l1: 19.1872 + 0.276821
# [1400]	cv_agg's l1: 19.1719 + 0.27616
# [1500]	cv_agg's l1: 19.1599 + 0.275687
# [1600]	cv_agg's l1: 19.1478 + 0.271153
# [1700]	cv_agg's l1: 19.1442 + 0.268978
# Run done, took: 3.25 s
# Starting run 3
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 150, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 28.0675 + 0.617622
# [200]	cv_agg's l1: 24.6711 + 0.547248
# [300]	cv_agg's l1: 22.5431 + 0.436484
# [400]	cv_agg's l1: 21.2821 + 0.376379
# [500]	cv_agg's l1: 20.5097 + 0.33672
# [600]	cv_agg's l1: 20.0537 + 0.305426
# [700]	cv_agg's l1: 19.7806 + 0.280519
# [800]	cv_agg's l1: 19.623 + 0.275073
# [900]	cv_agg's l1: 19.5301 + 0.264233
# [1000]	cv_agg's l1: 19.4798 + 0.260215
# [1100]	cv_agg's l1: 19.4514 + 0.253274
# [1200]	cv_agg's l1: 19.4398 + 0.247863
# Run done, took: 6.53 s
# Starting run 4
# {'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 500, 'num_threads': 4, 'objective': 'mae', 'verbose': -1}
# [100]	cv_agg's l1: 27.9219 + 0.581774
# [200]	cv_agg's l1: 24.4524 + 0.492414
# [300]	cv_agg's l1: 22.3313 + 0.41294
# [400]	cv_agg's l1: 21.1235 + 0.388327
# [500]	cv_agg's l1: 20.4245 + 0.354452
# [600]	cv_agg's l1: 20.0234 + 0.325409
# [700]	cv_agg's l1: 19.7929 + 0.31618
# [800]	cv_agg's l1: 19.6722 + 0.307498
# [900]	cv_agg's l1: 19.6105 + 0.2904
# [1000]	cv_agg's l1: 19.5829 + 0.278008
# [1100]	cv_agg's l1: 19.574 + 0.273994
# Run done, took: 10.27 s
# Best params: ({'bagging_fraction': 0.8, 'boosting': 'gbdt', 'feature_fraction': 0.8, 'learning_rate': 0.003, 'num_leaves': 7, 'num_threads': 4, 'objective': 'mae', 'verbose': -1, 'optimal_number_of_trees': 2930}, 19.111971994728922)
# Wall time: 23.7 s

# %% [markdown]
# ## Prediction

# %%
code5prediction = np.round(code5_model.predict(code5test[features])*2)/2
code5test = code5test.assign(fare_amount_prediction = code5prediction)

# %% [markdown]
# # Recombine all predictions and save

# %%
testResult = pd.concat([code1test,code2test,code3test,code4test,code5test])

# %%
testResult.to_csv("C:\\Users\\Leo\\Dropbox\\Info Göttingen\\Practical Course Data Science\\Task 2\\data\\test_prediction.csv")

# %%
testResult.fare_amount_prediction.describe()
# Out:
# count    64000.000000
# mean        22.987070
# std         23.388376
# min          3.000000
# 25%          7.500000
# 50%         12.000000
# 75%         31.500000
# max        244.000000
# Name: fare_amount_prediction, dtype: float64

# %%
testResult.describe()
# Out:
#          RatecodeID      VendorID     avg_speed     bridge  dropoff_latitude  \
# count  64000.000000  64000.000000  64000.000000  238.00000      64000.000000
# mean       1.406250      1.537047     14.546904    9.89916         40.746855
# std        0.913769      0.498630      9.388043    4.81803          0.047903
# min        1.000000      1.000000      0.014337    0.00000         40.045311
# 25%        1.000000      1.000000      8.153310    7.00000         40.725780
# 50%        1.000000      2.000000     11.716077   10.00000         40.751484
# 75%        1.000000      2.000000     18.140034   12.00000         40.768697
# max        5.000000      2.000000    176.170213   19.00000         41.525589
#
#        dropoff_longitude      duration  fare_amount_prediction            id  \
# count       64000.000000  64000.000000            64000.000000  64000.000000
# mean          -73.975568   1230.515344               22.987070  32000.500000
# std             0.084823   1080.955692               23.388376  18475.352951
# min           -74.833679     40.000000                3.000000      1.000000
# 25%           -73.993828    468.000000                7.500000  16000.750000
# 50%           -73.980309    858.000000               12.000000  32000.500000
# 75%           -73.960541   1659.000000               31.500000  48000.250000
# max           -72.551582   9931.000000              244.000000  64000.000000
#
#        improvement_surcharge      ...        outCityTripDistanceExtreme  \
# count           64000.000000      ...                        238.000000
# mean                0.299991      ...                         18.743958
# std                 0.001677      ...                          9.182369
# min                 0.000000      ...                          1.658264
# 25%                 0.300000      ...                         12.923967
# 50%                 0.300000      ...                         17.606952
# 75%                 0.300000      ...                         23.086686
# max                 0.300000      ...                         59.300306
#
#        out_of_city_distance  passenger_count  payment_type  pickup_latitude  \
# count            238.000000     64000.000000  64000.000000     64000.000000
# mean              12.461605         1.671188      1.337031        40.744481
# std                6.509709         1.303686      0.492926         0.037676
# min                0.662656         0.000000      1.000000        40.535580
# 25%                8.278194         1.000000      1.000000        40.732536
# 50%               11.964156         1.000000      1.000000        40.752197
# 75%               15.545136         2.000000      2.000000        40.766815
# max               37.757120         9.000000      4.000000        41.255787
#
#        pickup_longitude  ridesAtPickupHour  tolls_amount  \
# count      64000.000000       64000.000000   64000.00000
# mean         -73.960769       14415.856201       1.74787
# std            0.060701        3799.740583       4.14628
# min          -74.527763        1696.000000       0.00000
# 25%          -73.991264       13251.750000       0.00000
# 50%          -73.980370       14940.000000       0.00000
# 75%          -73.962111       16814.500000       0.00000
# max          -72.659561       20311.800000      82.50000
#
#        total_over_bridge_distance  trip_distance
# count                  238.000000   64000.000000
# mean                    16.208426       5.896713
# std                      6.321360       7.234262
# min                      1.763670       0.010000
# 25%                     12.896369       1.200000
# 50%                     15.435084       2.260000
# 75%                     18.683674       8.080000
# max                     39.327866      86.600000
#
# [8 rows x 25 columns]

# %%
testResult[testResult.fare_amount_prediction == testResult.fare_amount_prediction.max()]
# Out:
#        RatecodeID  VendorID  avg_speed  bridge     day  dropoff_latitude  \
# 62639           5         2  38.586170     NaN  Monday         40.866489
# 62698           5         1  40.170991     NaN  Sunday         40.754742
#
#        dropoff_longitude  duration endsInManhattan  fare_amount_prediction  \
# 62639         -74.398529    5582.0             NaN                   244.0
# 62698         -73.995575    6784.0             NaN                   244.0
#
#            ...        pickup_latitude  pickup_longitude  ridesAtPickupHour  \
# 62639      ...              40.644939        -73.781883           15776.75
# 62698      ...              40.742401        -74.000648           15583.00
#
#        startsInManhattan  store_and_fwd_flag  tolls_amount  \
# 62639                NaN                   N         18.04
# 62698                NaN                   N         10.50
#
#        total_over_bridge_distance  tpep_dropoff_datetime  \
# 62639                         NaN    2016-05-30 18:35:11
# 62698                         NaN    2016-05-08 03:19:36
#
#        tpep_pickup_datetime  trip_distance
# 62639   2016-05-30 17:02:09          59.83
# 62698   2016-05-08 01:26:32          75.70
#
# [2 rows x 32 columns]

# %%
testResult[testResult.trip_distance == testResult.trip_distance.max()]
# Out:
#        RatecodeID  VendorID  avg_speed  bridge       day  dropoff_latitude  \
# 62191           5         1  40.577899     NaN  Saturday         41.460213
#
#        dropoff_longitude  duration endsInManhattan  fare_amount_prediction  \
# 62191         -73.235245    7683.0             NaN                   240.0
#
#            ...        pickup_latitude  pickup_longitude  ridesAtPickupHour  \
# 62191      ...              40.643486        -73.789948            16038.5
#
#        startsInManhattan  store_and_fwd_flag  tolls_amount  \
# 62191                NaN                   N          7.62
#
#        total_over_bridge_distance  tpep_dropoff_datetime  \
# 62191                         NaN    2016-05-21 16:49:42
#
#        tpep_pickup_datetime  trip_distance
# 62191   2016-05-21 14:41:39           86.6
#
# [1 rows x 32 columns]

# %% [markdown]
# # Archive

# %% [markdown]
# ### Ratecode 1

# %%
import lightgbm as lgb

features = ["duration","passenger_count","trip_distance","payment_type","avg_speed"]

code1lgb_dataset = lgb.Dataset(code1data[features], label=code1data["fare_amount"])

params = {}
params['learning_rate'] = .05
params['boosting_type'] = 'gbdt'
params["objective"] = "regression"
params['min_samples_split'] = 3
params['min_samples_leaf'] = 15
params['max_features'] = 'sqrt'
params['max_depth'] = 10
params['subsample'] = 0.8

code1_model = lgb.train(params, code1lgb_dataset, 300)

# %% [markdown]
# ### Ratecode 4

# %%
#train models for the in city and out of city parts
code4_model_inner = RandomForestRegressor(random_state=1337)
code4_model_outer = RandomForestRegressor(random_state=1338)

#chose features
features_inner = ["passenger_count","in_city_distance","inCityTripDistanceExtreme","inCityTripDistance","payment_type"]
features_outer = ["passenger_count", "out_of_city_distance","outCityTripDistanceExtreme","payment_type"]

mixed_inner_train = code4data_mixed[features_inner]
mixed_outer_train = code4data_mixed[features_outer]

#fit the models
code4_model_inner.fit(mixed_inner_train,code4data_mixed["inCityFare"])
code4_model_outer.fit(mixed_outer_train,code4data_mixed["outCityFare"]);
